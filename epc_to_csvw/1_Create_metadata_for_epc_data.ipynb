# %% [markdown]
# # 1_Create_metadata_for_epc_data

# %% [markdown]
# # setup

# %%
import csvw_functions
import csv
import json
import rdflib

# %% [markdown]
# ## functions

# %% [markdown]
# ### get_glossary_info

# %%
with open('glossary_epc_domestic.txt') as f: glossary_text=f.read()

def get_glossary_info(col_name, st=glossary_text):
    ""
    a=st.find(col_name)
    b=st.find('\n',a+1)
    c=st.find('\n',b+1)
    
    variable_string=st[a+len(col_name):b].strip()
    
    description=st[b:c].strip()
    
    if not (variable_string.startswith('VARCHAR') 
            or variable_string.startswith('INT')
            or variable_string.startswith('DATE') 
            or variable_string.startswith('DECIMAL')
            or variable_string.startswith('DATETIME')
            or variable_string==''
           ):
    
        return get_glossary_info(col_name, st=st[a+len(col_name):])
    
    return col_name, variable_string, description

# %%
# test for single heading
get_glossary_info('LMK_KEY')
# Out:
# ('LMK_KEY',
#  'VARCHAR 64',
#  'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.')

# %%
# test for all headings
with open('certificates.csv') as f: 
    csvreader=csv.reader(f)
    headings=next(iter(csvreader))
for heading in headings:
    print(get_glossary_info(heading))
# Out:
# ('LMK_KEY', 'VARCHAR 64', 'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.')
# ('ADDRESS1', 'VARCHAR 84', 'First line of the address')
# ('ADDRESS2', 'VARCHAR 100', 'Second line of the address')
# ('ADDRESS3', 'VARCHAR 100', 'Third line of the address')
# ('POSTCODE', 'VARCHAR 8', 'The postcode of the property')
# ('BUILDING_REFERENCE_NUMBER', 'VARCHAR 12', 'Unique identifier for the property.')
# ('CURRENT_ENERGY_RATING', 'VARCHAR 8', "Current energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)")
# ('POTENTIAL_ENERGY_RATING', 'VARCHAR 8', "Estimated potential energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)")
# ('CURRENT_ENERGY_EFFICIENCY', 'INT', 'Based on cost of energy, i.e. energy required for space heating, water heating and lighting [in kWh/year] multiplied by fuel costs. (Â£/mÂ²/year where cost is derived from kWh).')
# ('POTENTIAL_ENERGY_EFFICIENCY', 'INT', 'The potential energy efficiency rating of the property.')
# ('PROPERTY_TYPE', 'VARCHAR 10', 'Describes the type of property such as House, Flat, Maisonette etc. This is the type differentiator for dwellings.')
# ('BUILT_FORM', 'VARCHAR 20', 'The building type of the Property e.g. Detached, Semi-Detached, Terrace etc. Together with the Property Type, the Build Form produces a structured description of the property')
# ('INSPECTION_DATE', 'DATE', 'The date that the inspection was actually carried out by the energy assessor')
# ('LOCAL_AUTHORITY', 'VARCHAR 9', 'Office for National Statistics (ONS) code. Local authority area in which the building is located.')
# ('CONSTITUENCY', 'VARCHAR 9', 'Office for National Statistics (ONS) code. Parliamentary constituency in which the building is located.')
# ('COUNTY', 'VARCHAR 24', 'County in which the building is located (where applicable)')
# ('LODGEMENT_DATE', 'DATE', 'Date lodged on the Energy Performance of Buildings Register')
# ('TRANSACTION_TYPE', 'VARCHAR 82', "Type of transaction that triggered EPC. For example, one of: marketed sale; non-marketed sale; new-dwelling; rental; not sale or rental; assessment for Green Deal; following Green Deal; FIT application; none of the above; RHI application; ECO assessment. Where the reason for the assessment is unknown by the energy assessor the transaction type will be recorded as 'none of the above'. Transaction types may be changed over time.")
# ('ENVIRONMENT_IMPACT_CURRENT', 'INT', "The Environmental Impact Rating. A measure of the property's current impact on the environment in terms of carbon dioxide (COâ‚‚) emissions. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)")
# ('ENVIRONMENT_IMPACT_POTENTIAL', 'INT', "The potential Environmental Impact Rating. A measure of the property's potential impact on the environment in terms of carbon dioxide (COâ‚‚) emissions after improvements have been carried out. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)")
# ('ENERGY_CONSUMPTION_CURRENT', 'INT', 'Current estimated total energy consumption for the property in a 12 month period (kWh/m2). Displayed on EPC as the current primary energy use per square metre of floor area.')
# ('ENERGY_CONSUMPTION_POTENTIAL', 'INT', 'Estimated potential total energy consumption for the Property in a 12 month period. Value is Kilowatt Hours per Square Metre (kWh/mÂ²)')
# ('CO2_EMISSIONS_CURRENT', 'DECIMAL', 'COâ‚‚ emissions per year in tonnes/year.')
# ('CO2_EMISS_CURR_PER_FLOOR_AREA', 'DECIMAL', 'COâ‚‚ emissions per square metre floor area per year in kg/mÂ²')
# ('CO2_EMISSIONS_POTENTIAL', 'DECIMAL', 'Estimated value in Tonnes per Year of the total COâ‚‚ emissions produced by the Property in 12 month period.')
# ('LIGHTING_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for lighting the property.')
# ('LIGHTING_COST_POTENTIAL', 'INT', 'GBP. Potential estimated annual energy costs for lighting the property after improvements have been made.')
# ('HEATING_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for heating the property.')
# ('HEATING_COST_POTENTIAL', 'INT', 'GBP. Potential annual energy costs for lighting the property after improvements have been made.')
# ('HOT_WATER_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for hot water')
# ('HOT_WATER_COST_POTENTIAL', 'INT', 'GBP. Potential estimated annual energy costs for hot water after improvements have been made.')
# ('TOTAL_FLOOR_AREA', 'DECIMAL', 'The total useful floor area is the total of all enclosed spaces measured to the internal face of the external walls, i.e. the gross floor area as measured in accordance with the guidance issued from time to time by the Royal Institute of Chartered Surveyors or by a body replacing that institution. (mÂ²)')
# ('ENERGY_TARIFF', 'VARCHAR 16', 'Type of electricity tariff for the property, e.g. single.')
# ('MAINS_GAS_FLAG', 'VARCHAR 1', 'Whether mains gas is available. Yes means that there is a gas meter or a gas-burning appliance in the dwelling. A closed-off gas pipe does not count.')
# ('FLOOR_LEVEL', 'VARCHAR 13', 'Flats and maisonettes only. Floor level relative to the lowest level of the property (0 for ground floor). If there is a basement, the basement is level 0 and the other floors are from 1 upwards')
# ('FLAT_TOP_STOREY', 'VARCHAR 1', 'Whether the flat is on the top storey')
# ('FLAT_STOREY_COUNT', 'INT', 'The number of storeys in the apartment block.')
# ('MAIN_HEATING_CONTROLS', 'VARCHAR 19', 'Type of main heating controls. Includes both main heating systems if there are two.')
# ('MULTI_GLAZE_PROPORTION', 'INT', 'The estimated banded range (e.g. 0% - 10%) of the total glazed area of the Property that is multiple glazed.')
# ('GLAZED_TYPE', 'VARCHAR 45', 'The type of glazing. From British Fenestration Rating Council or manufacturer declaration, one of; single; double; triple.')
# ('GLAZED_AREA', 'VARCHAR 22', 'Ranged estimate of the total glazed area of the Habitable Area.')
# ('EXTENSION_COUNT', 'INT', 'The number of extensions added to the property. Between 0 and 4.')
# ('NUMBER_HABITABLE_ROOMS', 'INT', 'Habitable rooms include any living room, sitting room, dining room, bedroom, study and similar; and also a non-separated conservatory. A kitchen/diner having a discrete seating area (with space for a table and four chairs) also counts as a habitable room. A non-separated conservatory adds to the habitable room count if it has an internal quality door between it and the dwelling. Excluded from the room count are any room used solely as a kitchen, utility room, bathroom, cloakroom, en-suite accommodation and similar and any hallway, stairs or landing; and also any room not having a window.')
# ('NUMBER_HEATED_ROOMS', 'INT', 'The number of heated rooms in the property if more than half of the habitable rooms are not heated.')
# ('LOW_ENERGY_LIGHTING', 'INT', 'The percentage of low energy lighting present in the property as a percentage of the total fixed lights in the property. 0% indicates that no low-energy lighting is present.')
# ('NUMBER_OPEN_FIREPLACES', 'INT', 'The number of Open Fireplaces in the Property. An Open Fireplace is a fireplace that still allows air to pass between the inside of the Property and the outside.')
# ('HOTWATER_DESCRIPTION', 'VARCHAR 95', 'Overall description of the property feature')
# ('HOT_WATER_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('HOT_WATER_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('FLOOR_DESCRIPTION', 'VARCHAR 91', 'Overall description of the property feature')
# ('FLOOR_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('FLOOR_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WINDOWS_DESCRIPTION', 'VARCHAR 54', 'Overall description of the property feature')
# ('WINDOWS_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WINDOWS_ENV_EFF', 'VARCHAR 9', 'WINDOWS. Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WALLS_DESCRIPTION', 'VARCHAR 121', 'Overall description of the property feature')
# ('WALLS_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WALLS_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('SECONDHEAT_DESCRIPTION', 'VARCHAR 97', 'Overall description of the property feature')
# ('SHEATING_ENERGY_EFF', 'VARCHAR 3', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('SHEATING_ENV_EFF', 'VARCHAR 3', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('ROOF_DESCRIPTION', 'VARCHAR 92', 'Overall description of the property feature')
# ('ROOF_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('ROOF_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEAT_DESCRIPTION', 'VARCHAR 134', 'Overall description of the property feature')
# ('MAINHEAT_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEAT_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEATCONT_DESCRIPTION', 'VARCHAR 96', 'Overall description of the property feature')
# ('MAINHEATC_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEATC_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('LIGHTING_DESCRIPTION', 'VARCHAR 91', 'Overall description of property feature. Total number of fixed lighting outlets and total number of low-energy fixed lighting outlets')
# ('LIGHTING_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('LIGHTING_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAIN_FUEL', 'VARCHAR 93', 'The type of fuel used to power the central heating e.g. Gas, Electricity')
# ('WIND_TURBINE_COUNT', 'INT', 'Number of wind turbines; 0 if none.')
# ('HEAT_LOSS_CORRIDOR', 'VARCHAR 17', 'Flats and maisonettes only. Indicates that the flat contains a corridor through which heat is lost. Heat loss corridor, one of: no corridor; heated corridor; unheated corridor')
# ('UNHEATED_CORRIDOR_LENGTH', 'DECIMAL', 'The total length of unheated corridor in the flat. Only populated if flat or maisonette contains unheated corridor. If unheated corridor, length of sheltered wall (mÂ²).')
# ('FLOOR_HEIGHT', 'DECIMAL', 'Average height of the storey in metres.')
# ('PHOTO_SUPPLY', 'INT', 'Percentage of photovoltaic area as a percentage of total roof area. 0% indicates that a Photovoltaic Supply is not present in the property.')
# ('SOLAR_WATER_HEATING_FLAG', 'VARCHAR 1', 'Indicates whether the heating in the Property is solar powered.')
# ('MECHANICAL_VENTILATION', 'VARCHAR 30', 'Identifies the type of mechanical ventilation the property has. This is required for the RdSAP calculation.')
# ('ADDRESS', '', 'Field containing the concatenation of address1, address2 and address3. Note that post code is recorded separately.')
# ('LOCAL_AUTHORITY_LABEL', '', 'The name of the local authority area in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Local Authority ONS Code.')
# ('CONSTITUENCY_LABEL', '', 'The name of the parliamentary constituency in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Constituency ONS Code.')
# ('POSTTOWN', 'VARCHAR 37', 'The post town of the property')
# ('CONSTRUCTION_AGE_BAND', 'VARCHAR 31', 'Age band when building part constructed. England & Wales only. One of: before 1900; 1900-1929; 1930-1949; 1950-1966; 1967-1975; 1976-1982; 1983-1990; 1991-1995; 1996-2002; 2003-2006; 2007-2011; 2012 onwards.')
# ('LODGEMENT_DATETIME', 'DATETIME2', 'Date and time lodged on the Energy Performance of Buildings Register.')
# ('TENURE', 'VARCHAR 100', 'Describes the tenure type of the property. One of: Owner-occupied; Rented (social); Rented (private).')
# ('FIXED_LIGHTING_OUTLETS_COUNT', 'INT', 'The number of fixed lighting outlets.')
# ('LOW_ENERGY_FIXED_LIGHT_COUNT', 'INT', 'The number of low-energy fixed lighting outlets.')
# ('UPRN', 'INT', 'The UPRN submitted by an assessor or alternatively from the departmentâ€™s address matching algorithm.')
# ('UPRN_SOURCE', 'VARCHAR 15', 'Populated with the values "Energy Assessor" or "Address Matched" to show how the UPRN was populated')

# %% [markdown]
# ### get_datatype

# %%
def get_datatype(variable_string):
    ""
    if variable_string=='':
        return 'string'
    elif variable_string.startswith('VARCHAR'):
        return 'string'
    elif variable_string.startswith('INT'):
        return 'integer'
    elif variable_string.startswith('DECIMAL'):
        return 'decimal'
    elif variable_string.startswith('DATETIME'):
        return {'base':'datetime','format':'yyyy-MM-dd HH:mm:ss'}
    elif variable_string.startswith('DATE'):
        return 'date'
    else:
        raise Exception

# %%
# check for all headings
for heading in headings:
    _, variable_string, description=get_glossary_info(heading)
    print(heading, get_datatype(variable_string))
# Out:
# LMK_KEY string
# ADDRESS1 string
# ADDRESS2 string
# ADDRESS3 string
# POSTCODE string
# BUILDING_REFERENCE_NUMBER string
# CURRENT_ENERGY_RATING string
# POTENTIAL_ENERGY_RATING string
# CURRENT_ENERGY_EFFICIENCY integer
# POTENTIAL_ENERGY_EFFICIENCY integer
# PROPERTY_TYPE string
# BUILT_FORM string
# INSPECTION_DATE date
# LOCAL_AUTHORITY string
# CONSTITUENCY string
# COUNTY string
# LODGEMENT_DATE date
# TRANSACTION_TYPE string
# ENVIRONMENT_IMPACT_CURRENT integer
# ENVIRONMENT_IMPACT_POTENTIAL integer
# ENERGY_CONSUMPTION_CURRENT integer
# ENERGY_CONSUMPTION_POTENTIAL integer
# CO2_EMISSIONS_CURRENT decimal
# CO2_EMISS_CURR_PER_FLOOR_AREA decimal
# CO2_EMISSIONS_POTENTIAL decimal
# LIGHTING_COST_CURRENT integer
# LIGHTING_COST_POTENTIAL integer
# HEATING_COST_CURRENT integer
# HEATING_COST_POTENTIAL integer
# HOT_WATER_COST_CURRENT integer
# HOT_WATER_COST_POTENTIAL integer
# TOTAL_FLOOR_AREA decimal
# ENERGY_TARIFF string
# MAINS_GAS_FLAG string
# FLOOR_LEVEL string
# FLAT_TOP_STOREY string
# FLAT_STOREY_COUNT integer
# MAIN_HEATING_CONTROLS string
# MULTI_GLAZE_PROPORTION integer
# GLAZED_TYPE string
# GLAZED_AREA string
# EXTENSION_COUNT integer
# NUMBER_HABITABLE_ROOMS integer
# NUMBER_HEATED_ROOMS integer
# LOW_ENERGY_LIGHTING integer
# NUMBER_OPEN_FIREPLACES integer
# HOTWATER_DESCRIPTION string
# HOT_WATER_ENERGY_EFF string
# HOT_WATER_ENV_EFF string
# FLOOR_DESCRIPTION string
# FLOOR_ENERGY_EFF string
# FLOOR_ENV_EFF string
# WINDOWS_DESCRIPTION string
# WINDOWS_ENERGY_EFF string
# WINDOWS_ENV_EFF string
# WALLS_DESCRIPTION string
# WALLS_ENERGY_EFF string
# WALLS_ENV_EFF string
# SECONDHEAT_DESCRIPTION string
# SHEATING_ENERGY_EFF string
# SHEATING_ENV_EFF string
# ROOF_DESCRIPTION string
# ROOF_ENERGY_EFF string
# ROOF_ENV_EFF string
# MAINHEAT_DESCRIPTION string
# MAINHEAT_ENERGY_EFF string
# MAINHEAT_ENV_EFF string
# MAINHEATCONT_DESCRIPTION string
# MAINHEATC_ENERGY_EFF string
# MAINHEATC_ENV_EFF string
# LIGHTING_DESCRIPTION string
# LIGHTING_ENERGY_EFF string
# LIGHTING_ENV_EFF string
# MAIN_FUEL string
# WIND_TURBINE_COUNT integer
# HEAT_LOSS_CORRIDOR string
# UNHEATED_CORRIDOR_LENGTH decimal
# FLOOR_HEIGHT decimal
# PHOTO_SUPPLY integer
# SOLAR_WATER_HEATING_FLAG string
# MECHANICAL_VENTILATION string
# ADDRESS string
# LOCAL_AUTHORITY_LABEL string
# CONSTITUENCY_LABEL string
# POSTTOWN string
# CONSTRUCTION_AGE_BAND string
# LODGEMENT_DATETIME {'base': 'datetime', 'format': 'yyyy-MM-dd HH:mm:ss'}
# TENURE string
# FIXED_LIGHTING_OUTLETS_COUNT integer
# LOW_ENERGY_FIXED_LIGHT_COUNT integer
# UPRN integer
# UPRN_SOURCE string

# %% [markdown]
# ## certificates

# %%
# get embedded metadata from csv file
embedded_metadata_dict=csvw_functions.get_embedded_metadata('certificates.csv', relative_path=True)

# include additional information on columns
columns=embedded_metadata_dict['tableSchema']['columns']
for i in range(len(columns)):
    column=columns[i]
    aboutUrl='http://example.com/epc_data#Certificate_{LMK_KEY}'
    heading, variable_string, description=get_glossary_info(column['name'])
    column['datatype']=get_datatype(variable_string)
    column['dc:description']=description
    column['propertyUrl']='http://example.com/epc_vocab#%s' % column['name']
    column['aboutUrl']=aboutUrl

# change some datatypes to fix errors in the glossart
def change_datatype(col_name,new_datatype):
    for x in embedded_metadata_dict['tableSchema']['columns']:
        if x['name']==col_name:
            x['datatype']=new_datatype
change_datatype('MULTI_GLAZE_PROPORTION','decimal')
change_datatype('EXTENSION_COUNT','decimal')
change_datatype('NUMBER_HABITABLE_ROOMS','decimal')
change_datatype('NUMBER_HEATED_ROOMS','decimal')
change_datatype('PHOTO_SUPPLY','decimal')

# create schema metadata dict
schema_metadata_dict=embedded_metadata_dict['tableSchema']
schema_metadata_dict["@context"]="http://www.w3.org/ns/csvw"
schema_metadata_dict["@type"]="Schema"

    
with open('certificates-schema-metadata.json','w') as f:
    json.dump(schema_metadata_dict,f,indent=4)
    
schema_metadata_dict
# Out:
# {'columns': [{'titles': {'und': ['LMK_KEY']},
#    'name': 'LMK_KEY',
#    'datatype': 'string',
#    'dc:description': 'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.',
#    'propertyUrl': 'http://example.com/epc_vocab#LMK_KEY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ADDRESS1']},
#    'name': 'ADDRESS1',
#    'datatype': 'string',
#    'dc:description': 'First line of the address',
#    'propertyUrl': 'http://example.com/epc_vocab#ADDRESS1',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ADDRESS2']},
#    'name': 'ADDRESS2',
#    'datatype': 'string',
#    'dc:description': 'Second line of the address',
#    'propertyUrl': 'http://example.com/epc_vocab#ADDRESS2',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ADDRESS3']},
#    'name': 'ADDRESS3',
#    'datatype': 'string',
#    'dc:description': 'Third line of the address',
#    'propertyUrl': 'http://example.com/epc_vocab#ADDRESS3',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['POSTCODE']},
#    'name': 'POSTCODE',
#    'datatype': 'string',
#    'dc:description': 'The postcode of the property',
#    'propertyUrl': 'http://example.com/epc_vocab#POSTCODE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['BUILDING_REFERENCE_NUMBER']},
#    'name': 'BUILDING_REFERENCE_NUMBER',
#    'datatype': 'string',
#    'dc:description': 'Unique identifier for the property.',
#    'propertyUrl': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CURRENT_ENERGY_RATING']},
#    'name': 'CURRENT_ENERGY_RATING',
#    'datatype': 'string',
#    'dc:description': "Current energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)",
#    'propertyUrl': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['POTENTIAL_ENERGY_RATING']},
#    'name': 'POTENTIAL_ENERGY_RATING',
#    'datatype': 'string',
#    'dc:description': "Estimated potential energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)",
#    'propertyUrl': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CURRENT_ENERGY_EFFICIENCY']},
#    'name': 'CURRENT_ENERGY_EFFICIENCY',
#    'datatype': 'integer',
#    'dc:description': 'Based on cost of energy, i.e. energy required for space heating, water heating and lighting [in kWh/year] multiplied by fuel costs. (Â£/mÂ²/year where cost is derived from kWh).',
#    'propertyUrl': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['POTENTIAL_ENERGY_EFFICIENCY']},
#    'name': 'POTENTIAL_ENERGY_EFFICIENCY',
#    'datatype': 'integer',
#    'dc:description': 'The potential energy efficiency rating of the property.',
#    'propertyUrl': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['PROPERTY_TYPE']},
#    'name': 'PROPERTY_TYPE',
#    'datatype': 'string',
#    'dc:description': 'Describes the type of property such as House, Flat, Maisonette etc. This is the type differentiator for dwellings.',
#    'propertyUrl': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['BUILT_FORM']},
#    'name': 'BUILT_FORM',
#    'datatype': 'string',
#    'dc:description': 'The building type of the Property e.g. Detached, Semi-Detached, Terrace etc. Together with the Property Type, the Build Form produces a structured description of the property',
#    'propertyUrl': 'http://example.com/epc_vocab#BUILT_FORM',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['INSPECTION_DATE']},
#    'name': 'INSPECTION_DATE',
#    'datatype': 'date',
#    'dc:description': 'The date that the inspection was actually carried out by the energy assessor',
#    'propertyUrl': 'http://example.com/epc_vocab#INSPECTION_DATE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LOCAL_AUTHORITY']},
#    'name': 'LOCAL_AUTHORITY',
#    'datatype': 'string',
#    'dc:description': 'Office for National Statistics (ONS) code. Local authority area in which the building is located.',
#    'propertyUrl': 'http://example.com/epc_vocab#LOCAL_AUTHORITY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CONSTITUENCY']},
#    'name': 'CONSTITUENCY',
#    'datatype': 'string',
#    'dc:description': 'Office for National Statistics (ONS) code. Parliamentary constituency in which the building is located.',
#    'propertyUrl': 'http://example.com/epc_vocab#CONSTITUENCY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['COUNTY']},
#    'name': 'COUNTY',
#    'datatype': 'string',
#    'dc:description': 'County in which the building is located (where applicable)',
#    'propertyUrl': 'http://example.com/epc_vocab#COUNTY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LODGEMENT_DATE']},
#    'name': 'LODGEMENT_DATE',
#    'datatype': 'date',
#    'dc:description': 'Date lodged on the Energy Performance of Buildings Register',
#    'propertyUrl': 'http://example.com/epc_vocab#LODGEMENT_DATE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['TRANSACTION_TYPE']},
#    'name': 'TRANSACTION_TYPE',
#    'datatype': 'string',
#    'dc:description': "Type of transaction that triggered EPC. For example, one of: marketed sale; non-marketed sale; new-dwelling; rental; not sale or rental; assessment for Green Deal; following Green Deal; FIT application; none of the above; RHI application; ECO assessment. Where the reason for the assessment is unknown by the energy assessor the transaction type will be recorded as 'none of the above'. Transaction types may be changed over time.",
#    'propertyUrl': 'http://example.com/epc_vocab#TRANSACTION_TYPE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ENVIRONMENT_IMPACT_CURRENT']},
#    'name': 'ENVIRONMENT_IMPACT_CURRENT',
#    'datatype': 'integer',
#    'dc:description': "The Environmental Impact Rating. A measure of the property's current impact on the environment in terms of carbon dioxide (COâ‚‚) emissions. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)",
#    'propertyUrl': 'http://example.com/epc_vocab#ENVIRONMENT_IMPACT_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ENVIRONMENT_IMPACT_POTENTIAL']},
#    'name': 'ENVIRONMENT_IMPACT_POTENTIAL',
#    'datatype': 'integer',
#    'dc:description': "The potential Environmental Impact Rating. A measure of the property's potential impact on the environment in terms of carbon dioxide (COâ‚‚) emissions after improvements have been carried out. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)",
#    'propertyUrl': 'http://example.com/epc_vocab#ENVIRONMENT_IMPACT_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ENERGY_CONSUMPTION_CURRENT']},
#    'name': 'ENERGY_CONSUMPTION_CURRENT',
#    'datatype': 'integer',
#    'dc:description': 'Current estimated total energy consumption for the property in a 12 month period (kWh/m2). Displayed on EPC as the current primary energy use per square metre of floor area.',
#    'propertyUrl': 'http://example.com/epc_vocab#ENERGY_CONSUMPTION_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ENERGY_CONSUMPTION_POTENTIAL']},
#    'name': 'ENERGY_CONSUMPTION_POTENTIAL',
#    'datatype': 'integer',
#    'dc:description': 'Estimated potential total energy consumption for the Property in a 12 month period. Value is Kilowatt Hours per Square Metre (kWh/mÂ²)',
#    'propertyUrl': 'http://example.com/epc_vocab#ENERGY_CONSUMPTION_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CO2_EMISSIONS_CURRENT']},
#    'name': 'CO2_EMISSIONS_CURRENT',
#    'datatype': 'decimal',
#    'dc:description': 'COâ‚‚ emissions per year in tonnes/year.',
#    'propertyUrl': 'http://example.com/epc_vocab#CO2_EMISSIONS_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CO2_EMISS_CURR_PER_FLOOR_AREA']},
#    'name': 'CO2_EMISS_CURR_PER_FLOOR_AREA',
#    'datatype': 'decimal',
#    'dc:description': 'COâ‚‚ emissions per square metre floor area per year in kg/mÂ²',
#    'propertyUrl': 'http://example.com/epc_vocab#CO2_EMISS_CURR_PER_FLOOR_AREA',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CO2_EMISSIONS_POTENTIAL']},
#    'name': 'CO2_EMISSIONS_POTENTIAL',
#    'datatype': 'decimal',
#    'dc:description': 'Estimated value in Tonnes per Year of the total COâ‚‚ emissions produced by the Property in 12 month period.',
#    'propertyUrl': 'http://example.com/epc_vocab#CO2_EMISSIONS_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LIGHTING_COST_CURRENT']},
#    'name': 'LIGHTING_COST_CURRENT',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Current estimated annual energy costs for lighting the property.',
#    'propertyUrl': 'http://example.com/epc_vocab#LIGHTING_COST_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LIGHTING_COST_POTENTIAL']},
#    'name': 'LIGHTING_COST_POTENTIAL',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Potential estimated annual energy costs for lighting the property after improvements have been made.',
#    'propertyUrl': 'http://example.com/epc_vocab#LIGHTING_COST_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HEATING_COST_CURRENT']},
#    'name': 'HEATING_COST_CURRENT',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Current estimated annual energy costs for heating the property.',
#    'propertyUrl': 'http://example.com/epc_vocab#HEATING_COST_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HEATING_COST_POTENTIAL']},
#    'name': 'HEATING_COST_POTENTIAL',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Potential annual energy costs for lighting the property after improvements have been made.',
#    'propertyUrl': 'http://example.com/epc_vocab#HEATING_COST_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HOT_WATER_COST_CURRENT']},
#    'name': 'HOT_WATER_COST_CURRENT',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Current estimated annual energy costs for hot water',
#    'propertyUrl': 'http://example.com/epc_vocab#HOT_WATER_COST_CURRENT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HOT_WATER_COST_POTENTIAL']},
#    'name': 'HOT_WATER_COST_POTENTIAL',
#    'datatype': 'integer',
#    'dc:description': 'GBP. Potential estimated annual energy costs for hot water after improvements have been made.',
#    'propertyUrl': 'http://example.com/epc_vocab#HOT_WATER_COST_POTENTIAL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['TOTAL_FLOOR_AREA']},
#    'name': 'TOTAL_FLOOR_AREA',
#    'datatype': 'decimal',
#    'dc:description': 'The total useful floor area is the total of all enclosed spaces measured to the internal face of the external walls, i.e. the gross floor area as measured in accordance with the guidance issued from time to time by the Royal Institute of Chartered Surveyors or by a body replacing that institution. (mÂ²)',
#    'propertyUrl': 'http://example.com/epc_vocab#TOTAL_FLOOR_AREA',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ENERGY_TARIFF']},
#    'name': 'ENERGY_TARIFF',
#    'datatype': 'string',
#    'dc:description': 'Type of electricity tariff for the property, e.g. single.',
#    'propertyUrl': 'http://example.com/epc_vocab#ENERGY_TARIFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINS_GAS_FLAG']},
#    'name': 'MAINS_GAS_FLAG',
#    'datatype': 'string',
#    'dc:description': 'Whether mains gas is available. Yes means that there is a gas meter or a gas-burning appliance in the dwelling. A closed-off gas pipe does not count.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINS_GAS_FLAG',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLOOR_LEVEL']},
#    'name': 'FLOOR_LEVEL',
#    'datatype': 'string',
#    'dc:description': 'Flats and maisonettes only. Floor level relative to the lowest level of the property (0 for ground floor). If there is a basement, the basement is level 0 and the other floors are from 1 upwards',
#    'propertyUrl': 'http://example.com/epc_vocab#FLOOR_LEVEL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLAT_TOP_STOREY']},
#    'name': 'FLAT_TOP_STOREY',
#    'datatype': 'string',
#    'dc:description': 'Whether the flat is on the top storey',
#    'propertyUrl': 'http://example.com/epc_vocab#FLAT_TOP_STOREY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLAT_STOREY_COUNT']},
#    'name': 'FLAT_STOREY_COUNT',
#    'datatype': 'integer',
#    'dc:description': 'The number of storeys in the apartment block.',
#    'propertyUrl': 'http://example.com/epc_vocab#FLAT_STOREY_COUNT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAIN_HEATING_CONTROLS']},
#    'name': 'MAIN_HEATING_CONTROLS',
#    'datatype': 'string',
#    'dc:description': 'Type of main heating controls. Includes both main heating systems if there are two.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAIN_HEATING_CONTROLS',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MULTI_GLAZE_PROPORTION']},
#    'name': 'MULTI_GLAZE_PROPORTION',
#    'datatype': 'decimal',
#    'dc:description': 'The estimated banded range (e.g. 0% - 10%) of the total glazed area of the Property that is multiple glazed.',
#    'propertyUrl': 'http://example.com/epc_vocab#MULTI_GLAZE_PROPORTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['GLAZED_TYPE']},
#    'name': 'GLAZED_TYPE',
#    'datatype': 'string',
#    'dc:description': 'The type of glazing. From British Fenestration Rating Council or manufacturer declaration, one of; single; double; triple.',
#    'propertyUrl': 'http://example.com/epc_vocab#GLAZED_TYPE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['GLAZED_AREA']},
#    'name': 'GLAZED_AREA',
#    'datatype': 'string',
#    'dc:description': 'Ranged estimate of the total glazed area of the Habitable Area.',
#    'propertyUrl': 'http://example.com/epc_vocab#GLAZED_AREA',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['EXTENSION_COUNT']},
#    'name': 'EXTENSION_COUNT',
#    'datatype': 'decimal',
#    'dc:description': 'The number of extensions added to the property. Between 0 and 4.',
#    'propertyUrl': 'http://example.com/epc_vocab#EXTENSION_COUNT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['NUMBER_HABITABLE_ROOMS']},
#    'name': 'NUMBER_HABITABLE_ROOMS',
#    'datatype': 'decimal',
#    'dc:description': 'Habitable rooms include any living room, sitting room, dining room, bedroom, study and similar; and also a non-separated conservatory. A kitchen/diner having a discrete seating area (with space for a table and four chairs) also counts as a habitable room. A non-separated conservatory adds to the habitable room count if it has an internal quality door between it and the dwelling. Excluded from the room count are any room used solely as a kitchen, utility room, bathroom, cloakroom, en-suite accommodation and similar and any hallway, stairs or landing; and also any room not having a window.',
#    'propertyUrl': 'http://example.com/epc_vocab#NUMBER_HABITABLE_ROOMS',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['NUMBER_HEATED_ROOMS']},
#    'name': 'NUMBER_HEATED_ROOMS',
#    'datatype': 'decimal',
#    'dc:description': 'The number of heated rooms in the property if more than half of the habitable rooms are not heated.',
#    'propertyUrl': 'http://example.com/epc_vocab#NUMBER_HEATED_ROOMS',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LOW_ENERGY_LIGHTING']},
#    'name': 'LOW_ENERGY_LIGHTING',
#    'datatype': 'integer',
#    'dc:description': 'The percentage of low energy lighting present in the property as a percentage of the total fixed lights in the property. 0% indicates that no low-energy lighting is present.',
#    'propertyUrl': 'http://example.com/epc_vocab#LOW_ENERGY_LIGHTING',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['NUMBER_OPEN_FIREPLACES']},
#    'name': 'NUMBER_OPEN_FIREPLACES',
#    'datatype': 'integer',
#    'dc:description': 'The number of Open Fireplaces in the Property. An Open Fireplace is a fireplace that still allows air to pass between the inside of the Property and the outside.',
#    'propertyUrl': 'http://example.com/epc_vocab#NUMBER_OPEN_FIREPLACES',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HOTWATER_DESCRIPTION']},
#    'name': 'HOTWATER_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#HOTWATER_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HOT_WATER_ENERGY_EFF']},
#    'name': 'HOT_WATER_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#HOT_WATER_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HOT_WATER_ENV_EFF']},
#    'name': 'HOT_WATER_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#HOT_WATER_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLOOR_DESCRIPTION']},
#    'name': 'FLOOR_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#FLOOR_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLOOR_ENERGY_EFF']},
#    'name': 'FLOOR_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#FLOOR_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLOOR_ENV_EFF']},
#    'name': 'FLOOR_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#FLOOR_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WINDOWS_DESCRIPTION']},
#    'name': 'WINDOWS_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#WINDOWS_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WINDOWS_ENERGY_EFF']},
#    'name': 'WINDOWS_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#WINDOWS_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WINDOWS_ENV_EFF']},
#    'name': 'WINDOWS_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'WINDOWS. Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#WINDOWS_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WALLS_DESCRIPTION']},
#    'name': 'WALLS_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#WALLS_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WALLS_ENERGY_EFF']},
#    'name': 'WALLS_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#WALLS_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WALLS_ENV_EFF']},
#    'name': 'WALLS_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#WALLS_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['SECONDHEAT_DESCRIPTION']},
#    'name': 'SECONDHEAT_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#SECONDHEAT_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['SHEATING_ENERGY_EFF']},
#    'name': 'SHEATING_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#SHEATING_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['SHEATING_ENV_EFF']},
#    'name': 'SHEATING_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#SHEATING_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ROOF_DESCRIPTION']},
#    'name': 'ROOF_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#ROOF_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ROOF_ENERGY_EFF']},
#    'name': 'ROOF_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#ROOF_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ROOF_ENV_EFF']},
#    'name': 'ROOF_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#ROOF_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEAT_DESCRIPTION']},
#    'name': 'MAINHEAT_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEAT_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEAT_ENERGY_EFF']},
#    'name': 'MAINHEAT_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEAT_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEAT_ENV_EFF']},
#    'name': 'MAINHEAT_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEAT_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEATCONT_DESCRIPTION']},
#    'name': 'MAINHEATCONT_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of the property feature',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEATCONT_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEATC_ENERGY_EFF']},
#    'name': 'MAINHEATC_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEATC_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAINHEATC_ENV_EFF']},
#    'name': 'MAINHEATC_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#MAINHEATC_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LIGHTING_DESCRIPTION']},
#    'name': 'LIGHTING_DESCRIPTION',
#    'datatype': 'string',
#    'dc:description': 'Overall description of property feature. Total number of fixed lighting outlets and total number of low-energy fixed lighting outlets',
#    'propertyUrl': 'http://example.com/epc_vocab#LIGHTING_DESCRIPTION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LIGHTING_ENERGY_EFF']},
#    'name': 'LIGHTING_ENERGY_EFF',
#    'datatype': 'string',
#    'dc:description': 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#LIGHTING_ENERGY_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LIGHTING_ENV_EFF']},
#    'name': 'LIGHTING_ENV_EFF',
#    'datatype': 'string',
#    'dc:description': 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.',
#    'propertyUrl': 'http://example.com/epc_vocab#LIGHTING_ENV_EFF',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MAIN_FUEL']},
#    'name': 'MAIN_FUEL',
#    'datatype': 'string',
#    'dc:description': 'The type of fuel used to power the central heating e.g. Gas, Electricity',
#    'propertyUrl': 'http://example.com/epc_vocab#MAIN_FUEL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['WIND_TURBINE_COUNT']},
#    'name': 'WIND_TURBINE_COUNT',
#    'datatype': 'integer',
#    'dc:description': 'Number of wind turbines; 0 if none.',
#    'propertyUrl': 'http://example.com/epc_vocab#WIND_TURBINE_COUNT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['HEAT_LOSS_CORRIDOR']},
#    'name': 'HEAT_LOSS_CORRIDOR',
#    'datatype': 'string',
#    'dc:description': 'Flats and maisonettes only. Indicates that the flat contains a corridor through which heat is lost. Heat loss corridor, one of: no corridor; heated corridor; unheated corridor',
#    'propertyUrl': 'http://example.com/epc_vocab#HEAT_LOSS_CORRIDOR',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['UNHEATED_CORRIDOR_LENGTH']},
#    'name': 'UNHEATED_CORRIDOR_LENGTH',
#    'datatype': 'decimal',
#    'dc:description': 'The total length of unheated corridor in the flat. Only populated if flat or maisonette contains unheated corridor. If unheated corridor, length of sheltered wall (mÂ²).',
#    'propertyUrl': 'http://example.com/epc_vocab#UNHEATED_CORRIDOR_LENGTH',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FLOOR_HEIGHT']},
#    'name': 'FLOOR_HEIGHT',
#    'datatype': 'decimal',
#    'dc:description': 'Average height of the storey in metres.',
#    'propertyUrl': 'http://example.com/epc_vocab#FLOOR_HEIGHT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['PHOTO_SUPPLY']},
#    'name': 'PHOTO_SUPPLY',
#    'datatype': 'decimal',
#    'dc:description': 'Percentage of photovoltaic area as a percentage of total roof area. 0% indicates that a Photovoltaic Supply is not present in the property.',
#    'propertyUrl': 'http://example.com/epc_vocab#PHOTO_SUPPLY',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['SOLAR_WATER_HEATING_FLAG']},
#    'name': 'SOLAR_WATER_HEATING_FLAG',
#    'datatype': 'string',
#    'dc:description': 'Indicates whether the heating in the Property is solar powered.',
#    'propertyUrl': 'http://example.com/epc_vocab#SOLAR_WATER_HEATING_FLAG',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['MECHANICAL_VENTILATION']},
#    'name': 'MECHANICAL_VENTILATION',
#    'datatype': 'string',
#    'dc:description': 'Identifies the type of mechanical ventilation the property has. This is required for the RdSAP calculation.',
#    'propertyUrl': 'http://example.com/epc_vocab#MECHANICAL_VENTILATION',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['ADDRESS']},
#    'name': 'ADDRESS',
#    'datatype': 'string',
#    'dc:description': 'Field containing the concatenation of address1, address2 and address3. Note that post code is recorded separately.',
#    'propertyUrl': 'http://example.com/epc_vocab#ADDRESS',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LOCAL_AUTHORITY_LABEL']},
#    'name': 'LOCAL_AUTHORITY_LABEL',
#    'datatype': 'string',
#    'dc:description': 'The name of the local authority area in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Local Authority ONS Code.',
#    'propertyUrl': 'http://example.com/epc_vocab#LOCAL_AUTHORITY_LABEL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CONSTITUENCY_LABEL']},
#    'name': 'CONSTITUENCY_LABEL',
#    'datatype': 'string',
#    'dc:description': 'The name of the parliamentary constituency in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Constituency ONS Code.',
#    'propertyUrl': 'http://example.com/epc_vocab#CONSTITUENCY_LABEL',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['POSTTOWN']},
#    'name': 'POSTTOWN',
#    'datatype': 'string',
#    'dc:description': 'The post town of the property',
#    'propertyUrl': 'http://example.com/epc_vocab#POSTTOWN',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['CONSTRUCTION_AGE_BAND']},
#    'name': 'CONSTRUCTION_AGE_BAND',
#    'datatype': 'string',
#    'dc:description': 'Age band when building part constructed. England & Wales only. One of: before 1900; 1900-1929; 1930-1949; 1950-1966; 1967-1975; 1976-1982; 1983-1990; 1991-1995; 1996-2002; 2003-2006; 2007-2011; 2012 onwards.',
#    'propertyUrl': 'http://example.com/epc_vocab#CONSTRUCTION_AGE_BAND',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LODGEMENT_DATETIME']},
#    'name': 'LODGEMENT_DATETIME',
#    'datatype': {'base': 'datetime', 'format': 'yyyy-MM-dd HH:mm:ss'},
#    'dc:description': 'Date and time lodged on the Energy Performance of Buildings Register.',
#    'propertyUrl': 'http://example.com/epc_vocab#LODGEMENT_DATETIME',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['TENURE']},
#    'name': 'TENURE',
#    'datatype': 'string',
#    'dc:description': 'Describes the tenure type of the property. One of: Owner-occupied; Rented (social); Rented (private).',
#    'propertyUrl': 'http://example.com/epc_vocab#TENURE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['FIXED_LIGHTING_OUTLETS_COUNT']},
#    'name': 'FIXED_LIGHTING_OUTLETS_COUNT',
#    'datatype': 'integer',
#    'dc:description': 'The number of fixed lighting outlets.',
#    'propertyUrl': 'http://example.com/epc_vocab#FIXED_LIGHTING_OUTLETS_COUNT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['LOW_ENERGY_FIXED_LIGHT_COUNT']},
#    'name': 'LOW_ENERGY_FIXED_LIGHT_COUNT',
#    'datatype': 'integer',
#    'dc:description': 'The number of low-energy fixed lighting outlets.',
#    'propertyUrl': 'http://example.com/epc_vocab#LOW_ENERGY_FIXED_LIGHT_COUNT',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['UPRN']},
#    'name': 'UPRN',
#    'datatype': 'integer',
#    'dc:description': 'The UPRN submitted by an assessor or alternatively from the departmentâ€™s address matching algorithm.',
#    'propertyUrl': 'http://example.com/epc_vocab#UPRN',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'},
#   {'titles': {'und': ['UPRN_SOURCE']},
#    'name': 'UPRN_SOURCE',
#    'datatype': 'string',
#    'dc:description': 'Populated with the values "Energy Assessor" or "Address Matched" to show how the UPRN was populated',
#    'propertyUrl': 'http://example.com/epc_vocab#UPRN_SOURCE',
#    'aboutUrl': 'http://example.com/epc_data#Certificate_{LMK_KEY}'}],
#  '@context': 'http://www.w3.org/ns/csvw',
#  '@type': 'Schema'}

# %%
annotated_table_group_dict=csvw_functions.create_annotated_table_group('certificates-metadata.json')
csvw_functions.display_annotated_table_group_dict(annotated_table_group_dict)
# Out:
# {'id': None,
#  'notes': False,
#  'tables': [{'columns': [{'table': '__recursion__',
#      'number': 1,
#      'sourceNumber': 1,
#      'name': 'LMK_KEY',
#      'titles': [{'@value': 'LMK_KEY', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'value': {'@value': '63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'value': {'@value': 'c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'value': {'@value': 'e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'value': {'@value': '92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'value': {'@value': 'cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LMK_KEY',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.'}},
#     {'table': '__recursion__',
#      'number': 2,
#      'sourceNumber': 2,
#      'name': 'ADDRESS1',
#      'titles': [{'@value': 'ADDRESS1', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS1',
#        'valueURL': None}],
#      'dc:description': {'@value': 'First line of the address'}},
#     {'table': '__recursion__',
#      'number': 3,
#      'sourceNumber': 3,
#      'name': 'ADDRESS2',
#      'titles': [{'@value': 'ADDRESS2', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS2',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Second line of the address'}},
#     {'table': '__recursion__',
#      'number': 4,
#      'sourceNumber': 4,
#      'name': 'ADDRESS3',
#      'titles': [{'@value': 'ADDRESS3', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS3',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Third line of the address'}},
#     {'table': '__recursion__',
#      'number': 5,
#      'sourceNumber': 5,
#      'name': 'POSTCODE',
#      'titles': [{'@value': 'POSTCODE', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#POSTCODE',
#        'valueURL': None}],
#      'dc:description': {'@value': 'The postcode of the property'}},
#     {'table': '__recursion__',
#      'number': 6,
#      'sourceNumber': 6,
#      'name': 'BUILDING_REFERENCE_NUMBER',
#      'titles': [{'@value': 'BUILDING_REFERENCE_NUMBER', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10002887813',
#        'value': {'@value': '10002887813',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10002800418',
#        'value': {'@value': '10002800418',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10002745187',
#        'value': {'@value': '10002745187',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10002604718',
#        'value': {'@value': '10002604718',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10002572726',
#        'value': {'@value': '10002572726',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#BUILDING_REFERENCE_NUMBER',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Unique identifier for the property.'}},
#     {'table': '__recursion__',
#      'number': 7,
#      'sourceNumber': 7,
#      'name': 'CURRENT_ENERGY_RATING',
#      'titles': [{'@value': 'CURRENT_ENERGY_RATING', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'D',
#        'value': {'@value': 'D',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'D',
#        'value': {'@value': 'D',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'C',
#        'value': {'@value': 'C',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'D',
#        'value': {'@value': 'D',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'E',
#        'value': {'@value': 'E',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_RATING',
#        'valueURL': None}],
#      'dc:description': {'@value': "Current energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)"}},
#     {'table': '__recursion__',
#      'number': 8,
#      'sourceNumber': 8,
#      'name': 'POTENTIAL_ENERGY_RATING',
#      'titles': [{'@value': 'POTENTIAL_ENERGY_RATING', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'B',
#        'value': {'@value': 'B',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'B',
#        'value': {'@value': 'B',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'B',
#        'value': {'@value': 'B',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'B',
#        'value': {'@value': 'B',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'B',
#        'value': {'@value': 'B',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_RATING',
#        'valueURL': None}],
#      'dc:description': {'@value': "Estimated potential energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)"}},
#     {'table': '__recursion__',
#      'number': 9,
#      'sourceNumber': 9,
#      'name': 'CURRENT_ENERGY_EFFICIENCY',
#      'titles': [{'@value': 'CURRENT_ENERGY_EFFICIENCY', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'integer'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '66',
#        'value': {'@value': 66,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '64',
#        'value': {'@value': 64,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '71',
#        'value': {'@value': 71,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '68',
#        'value': {'@value': 68,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '53',
#        'value': {'@value': 53,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#CURRENT_ENERGY_EFFICIENCY',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Based on cost of energy, i.e. energy required for space heating, water heating and lighting [in kWh/year] multiplied by fuel costs. (Â£/mÂ²/year where cost is derived from kWh).'}},
#     {'table': '__recursion__',
#      'number': 10,
#      'sourceNumber': 10,
#      'name': 'POTENTIAL_ENERGY_EFFICIENCY',
#      'titles': [{'@value': 'POTENTIAL_ENERGY_EFFICIENCY', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'integer'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '88',
#        'value': {'@value': 88,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '85',
#        'value': {'@value': 85,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '85',
#        'value': {'@value': 85,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '88',
#        'value': {'@value': 88,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '83',
#        'value': {'@value': 83,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#POTENTIAL_ENERGY_EFFICIENCY',
#        'valueURL': None}],
#      'dc:description': {'@value': 'The potential energy efficiency rating of the property.'}},
#     {'table': '__recursion__',
#      'number': 11,
#      'sourceNumber': 11,
#      'name': 'PROPERTY_TYPE',
#      'titles': [{'@value': 'PROPERTY_TYPE', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'House',
#        'value': {'@value': 'House',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Bungalow',
#        'value': {'@value': 'Bungalow',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'House',
#        'value': {'@value': 'House',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'House',
#        'value': {'@value': 'House',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'House',
#        'value': {'@value': 'House',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#PROPERTY_TYPE',
#        'valueURL': None}],
#      'dc:description': {'@value': 'Describes the type of property such as House, Flat, Maisonette etc. This is the type differentiator for dwellings.'}},
#     {'table': '__recursion__',
#      'number': 12,
#      'sourceNumber': 12,
#      'name': 'BUILT_FORM',
#      'titles': [{'@value': 'BUILT_FORM', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Semi-Detached',
#        'value': {'@value': 'Semi-Detached',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Detached',
#        'value': {'@value': 'Detached',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Semi-Detached',
#        'value': {'@value': 'Semi-Detached',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Mid-Terrace',
#        'value': {'@value': 'Mid-Terrace',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Detached',
#        'value': {'@value': 'Detached',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#BUILT_FORM',
#        'valueURL': None}],
#      'dc:description': {'@value': 'The building type of the Property e.g. Detached, Semi-Detached, Terrace etc. Together with the Property Type, the Build Form produces a structured description of the property'}},
#     {'table': '__recursion__',
#      'number': 13,
#      'sourceNumber': 13,
#      'name': 'INSPECTION_DATE',
#      'titles': [{'@value': 'INSPECTION_DATE', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'date'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-30',
#        'value': {'@value': '2022-06-30',
#         '@type': 'http://www.w3.org/2001/XMLSchema#date'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-27',
#        'value': {'@value': '2022-06-27',
#         '@type': 'http://www.w3.org/2001/XMLSchema#date'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-30',
#        'value': {'@value': '2022-06-30',
#         '@type': 'http://www.w3.org/2001/XMLSchema#date'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e',
#        'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-30',
#        'value': {'@value': '2022-06-30',
#         '@type': 'http://www.w3.org/2001/XMLSchema#date'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee',
#        'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-30',
#        'value': {'@value': '2022-06-30',
#         '@type': 'http://www.w3.org/2001/XMLSchema#date'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#INSPECTION_DATE',
#        'valueURL': None}],
#      'dc:description': {'@value': 'The date that the inspection was actually carried out by the energy assessor'}},
#     {'table': '__recursion__',
#      'number': 14,
#      'sourceNumber': 14,
#      'name': 'LOCAL_AUTHORITY',
#      'titles': [{'@value': 'LOCAL_AUTHORITY', '@language': 'und'}],
#      'virtual': False,
#      'suppressOutput': False,
#      'datatype': {'base': 'string'},
#      'default': '',
#      'lang': 'und',
#      'null': '',
#      'ordered': False,
#      'required': False,
#      'separator': None,
#      'textDirection': 'auto',
#      'aboutURL': 'http://example.com/epc_data#Certificate_{LMK_KEY}',
#      'propertyURL': 'http://example.com/epc_vocab#LOCAL_AUTHORITY',
#      'valueURL': None,
#      'cells': [{'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'E07000130',
#        'value': {'@value': 'E07000130',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045',
#        'propertyURL': 'http://example.com/epc_vocab#LOCAL_AUTHORITY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'E07000130',
#        'value': {'@value': 'E07000130',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2',
#        'propertyURL': 'http://example.com/epc_vocab#LOCAL_AUTHORITY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'E07000130',
#        'value': {'@value': 'E07000130',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
# ...
#        'propertyURL': 'http://example.com/epc_vocab#ROOF_ENV_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Boiler and radiators, mains gas',
#        'value': {'@value': 'Boiler and radiators, mains gas',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEAT_DESCRIPTION',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Good',
#        'value': {'@value': 'Good',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEAT_ENERGY_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Good',
#        'value': {'@value': 'Good',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEAT_ENV_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Programmer and room thermostat',
#        'value': {'@value': 'Programmer and room thermostat',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEATCONT_DESCRIPTION',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Average',
#        'value': {'@value': 'Average',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEATC_ENERGY_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Average',
#        'value': {'@value': 'Average',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAINHEATC_ENV_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Low energy lighting in 20% of fixed outlets',
#        'value': {'@value': 'Low energy lighting in 20% of fixed outlets',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LIGHTING_DESCRIPTION',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Poor',
#        'value': {'@value': 'Poor',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LIGHTING_ENERGY_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Poor',
#        'value': {'@value': 'Poor',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LIGHTING_ENV_EFF',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'mains gas (not community)',
#        'value': {'@value': 'mains gas (not community)',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MAIN_FUEL',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '0',
#        'value': {'@value': 0,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#WIND_TURBINE_COUNT',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '',
#        'value': None,
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#HEAT_LOSS_CORRIDOR',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '',
#        'value': None,
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#UNHEATED_CORRIDOR_LENGTH',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2.6',
#        'value': {'@value': 2.6,
#         '@type': 'http://www.w3.org/2001/XMLSchema#decimal'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#FLOOR_HEIGHT',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '0.0',
#        'value': {'@value': 0.0,
#         '@type': 'http://www.w3.org/2001/XMLSchema#decimal'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#PHOTO_SUPPLY',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'N',
#        'value': {'@value': 'N',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#SOLAR_WATER_HEATING_FLAG',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'natural',
#        'value': {'@value': 'natural',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#MECHANICAL_VENTILATION',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '__REMOVED__',
#        'value': {'@value': '__REMOVED__',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#ADDRESS',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Blaby',
#        'value': {'@value': 'Blaby',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LOCAL_AUTHORITY_LABEL',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Charnwood',
#        'value': {'@value': 'Charnwood',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#CONSTITUENCY_LABEL',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'LEICESTER',
#        'value': {'@value': 'LEICESTER',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#POSTTOWN',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'England and Wales: 1930-1949',
#        'value': {'@value': 'England and Wales: 1930-1949',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#CONSTRUCTION_AGE_BAND',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '2022-06-30 15:32:19',
#        'value': {'@value': '2022-06-30T15:32:19',
#         '@type': 'http://www.w3.org/2001/XMLSchema#dateTime'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LODGEMENT_DATETIME',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Owner-occupied',
#        'value': {'@value': 'Owner-occupied',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#TENURE',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '10',
#        'value': {'@value': 10,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#FIXED_LIGHTING_OUTLETS_COUNT',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '',
#        'value': None,
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#LOW_ENERGY_FIXED_LIGHT_COUNT',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': '100030393988',
#        'value': {'@value': 100030393988,
#         '@type': 'http://www.w3.org/2001/XMLSchema#integer'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#UPRN',
#        'valueURL': None},
#       {'table': '__recursion__',
#        'column': '__recursion__',
#        'row': '__recursion__',
#        'stringValue': 'Energy Assessor',
#        'value': {'@value': 'Energy Assessor',
#         '@type': 'http://www.w3.org/2001/XMLSchema#string',
#         '@language': 'und'},
#        'errors': [],
#        'textDirection': 'auto',
#        'ordered': False,
#        'aboutURL': 'http://example.com/epc_data#Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389',
#        'propertyURL': 'http://example.com/epc_vocab#UPRN_SOURCE',
#        'valueURL': None}],
#      'titles': []}],
#    'id': None,
#    'url': 'file:///C:/Users/cvskf/OneDrive - Loughborough University/_Git/stevenkfirth/3DFAIR/epc_to_csvw/certificates.csv',
#    'tableDirection': 'auto',
#    'suppressOutput': False,
#    'notes': [],
#    'foreignKeys': '__recursion__',
#    'transformations': [],
#    'schema': 'file:///C:/Users/cvskf/OneDrive - Loughborough University/_Git/stevenkfirth/3DFAIR/epc_to_csvw/certificates-schema-metadata.json'}]}

# %%
csvw_functions.get_errors(annotated_table_group_dict)
# Out:
# []

# %% [markdown]
# ### convert to rdf

# %%
rdf_ntriples=csvw_functions.create_rdf(annotated_table_group_dict,mode='minimal')
g=rdflib.Graph().parse(data=rdf_ntriples, format='ntriples')
g.serialize('certificates.ttl',format='ttl')
g.bind('sosa',rdflib.SOSA)
g.bind('epc_data',rdflib.URIRef('http://example.com/epc_data#'))
g.bind('epc_vocab',rdflib.URIRef('http://example.com/epc_vocab#'))
print(g.serialize(format='ttl'))
# Out:
# @prefix epc_data: <http://example.com/epc_data#> .
# @prefix ns1: <http://example.com/epc_vocab#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# epc_data:Certificate_63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045 ns1:ADDRESS "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS1 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS2 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS3 "__REMOVED__"^^xsd:string ;
#     ns1:BUILDING_REFERENCE_NUMBER "10002887813"^^xsd:string ;
#     ns1:BUILT_FORM "Semi-Detached"^^xsd:string ;
#     ns1:CO2_EMISSIONS_CURRENT 2.9 ;
#     ns1:CO2_EMISSIONS_POTENTIAL 0.9 ;
#     ns1:CO2_EMISS_CURR_PER_FLOOR_AREA 38.0 ;
#     ns1:CONSTITUENCY "E14000625"^^xsd:string ;
#     ns1:CONSTITUENCY_LABEL "Charnwood"^^xsd:string ;
#     ns1:CONSTRUCTION_AGE_BAND "England and Wales: 1900-1929"^^xsd:string ;
#     ns1:COUNTY "Leicestershire"^^xsd:string ;
#     ns1:CURRENT_ENERGY_EFFICIENCY 66 ;
#     ns1:CURRENT_ENERGY_RATING "D"^^xsd:string ;
#     ns1:ENERGY_CONSUMPTION_CURRENT 239 ;
#     ns1:ENERGY_CONSUMPTION_POTENTIAL 74 ;
#     ns1:ENERGY_TARIFF "dual"^^xsd:string ;
#     ns1:ENVIRONMENT_IMPACT_CURRENT 67 ;
#     ns1:ENVIRONMENT_IMPACT_POTENTIAL 90 ;
#     ns1:EXTENSION_COUNT 0.0 ;
#     ns1:FIXED_LIGHTING_OUTLETS_COUNT 18 ;
#     ns1:FLOOR_DESCRIPTION "Solid, no insulation (assumed)"^^xsd:string ;
#     ns1:FLOOR_HEIGHT 2.4 ;
#     ns1:GLAZED_AREA "Normal"^^xsd:string ;
#     ns1:GLAZED_TYPE "secondary glazing"^^xsd:string ;
#     ns1:HEATING_COST_CURRENT 589 ;
#     ns1:HEATING_COST_POTENTIAL 387 ;
#     ns1:HOTWATER_DESCRIPTION "From main system"^^xsd:string ;
#     ns1:HOT_WATER_COST_CURRENT 76 ;
#     ns1:HOT_WATER_COST_POTENTIAL 53 ;
#     ns1:HOT_WATER_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:HOT_WATER_ENV_EFF "Good"^^xsd:string ;
#     ns1:INSPECTION_DATE "2022-06-30"^^xsd:date ;
#     ns1:LIGHTING_COST_CURRENT 72 ;
#     ns1:LIGHTING_COST_POTENTIAL 72 ;
#     ns1:LIGHTING_DESCRIPTION "Low energy lighting in all fixed outlets"^^xsd:string ;
#     ns1:LIGHTING_ENERGY_EFF "Very Good"^^xsd:string ;
#     ns1:LIGHTING_ENV_EFF "Very Good"^^xsd:string ;
#     ns1:LMK_KEY "63ff1a3a9c341ac8c4bc081160d572dfc98e7fa98dc5244d3620cd22ada45045"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY "E07000130"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY_LABEL "Charnwood"^^xsd:string ;
#     ns1:LODGEMENT_DATE "2022-06-30"^^xsd:date ;
#     ns1:LODGEMENT_DATETIME "2022-06-30T12:45:08"^^xsd:dateTime ;
#     ns1:LOW_ENERGY_LIGHTING 100 ;
#     ns1:MAINHEATCONT_DESCRIPTION "Programmer, room thermostat and TRVs"^^xsd:string ;
#     ns1:MAINHEATC_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEATC_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_DESCRIPTION "Boiler and radiators, mains gas"^^xsd:string ;
#     ns1:MAINHEAT_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINS_GAS_FLAG "Y"^^xsd:string ;
#     ns1:MAIN_FUEL "mains gas (not community)"^^xsd:string ;
#     ns1:MECHANICAL_VENTILATION "natural"^^xsd:string ;
#     ns1:MULTI_GLAZE_PROPORTION 100.0 ;
#     ns1:NUMBER_HABITABLE_ROOMS 3.0 ;
#     ns1:NUMBER_HEATED_ROOMS 3.0 ;
#     ns1:NUMBER_OPEN_FIREPLACES 0 ;
#     ns1:PHOTO_SUPPLY 0.0 ;
#     ns1:POSTCODE "__REMOVED__"^^xsd:string ;
#     ns1:POSTTOWN "LEICESTER"^^xsd:string ;
#     ns1:POTENTIAL_ENERGY_EFFICIENCY 88 ;
#     ns1:POTENTIAL_ENERGY_RATING "B"^^xsd:string ;
#     ns1:PROPERTY_TYPE "House"^^xsd:string ;
#     ns1:ROOF_DESCRIPTION "Pitched, 300 mm loft insulation"^^xsd:string ;
#     ns1:ROOF_ENERGY_EFF "Very Good"^^xsd:string ;
#     ns1:ROOF_ENV_EFF "Very Good"^^xsd:string ;
#     ns1:SECONDHEAT_DESCRIPTION "Room heaters, wood logs"^^xsd:string ;
#     ns1:SOLAR_WATER_HEATING_FLAG "N"^^xsd:string ;
#     ns1:TENURE "Owner-occupied"^^xsd:string ;
#     ns1:TOTAL_FLOOR_AREA 77.0 ;
#     ns1:TRANSACTION_TYPE "non marketed sale"^^xsd:string ;
#     ns1:UPRN 100030428320 ;
#     ns1:UPRN_SOURCE "Energy Assessor"^^xsd:string ;
#     ns1:WALLS_DESCRIPTION "Solid brick, as built, no insulation (assumed)"^^xsd:string ;
#     ns1:WALLS_ENERGY_EFF "Poor"^^xsd:string ;
#     ns1:WALLS_ENV_EFF "Poor"^^xsd:string ;
#     ns1:WINDOWS_DESCRIPTION "Full secondary glazing"^^xsd:string ;
#     ns1:WINDOWS_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:WINDOWS_ENV_EFF "Good"^^xsd:string ;
#     ns1:WIND_TURBINE_COUNT 0 .
#
# epc_data:Certificate_92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee ns1:ADDRESS "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS1 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS2 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS3 "__REMOVED__"^^xsd:string ;
#     ns1:BUILDING_REFERENCE_NUMBER "10002604718"^^xsd:string ;
#     ns1:BUILT_FORM "Mid-Terrace"^^xsd:string ;
#     ns1:CO2_EMISSIONS_CURRENT 2.6 ;
#     ns1:CO2_EMISSIONS_POTENTIAL 0.9 ;
#     ns1:CO2_EMISS_CURR_PER_FLOOR_AREA 44.0 ;
#     ns1:CONSTITUENCY "E14000625"^^xsd:string ;
#     ns1:CONSTITUENCY_LABEL "Charnwood"^^xsd:string ;
#     ns1:CONSTRUCTION_AGE_BAND "England and Wales: 1996-2002"^^xsd:string ;
#     ns1:COUNTY "Leicestershire"^^xsd:string ;
#     ns1:CURRENT_ENERGY_EFFICIENCY 68 ;
#     ns1:CURRENT_ENERGY_RATING "D"^^xsd:string ;
#     ns1:ENERGY_CONSUMPTION_CURRENT 250 ;
#     ns1:ENERGY_CONSUMPTION_POTENTIAL 87 ;
#     ns1:ENERGY_TARIFF "Single"^^xsd:string ;
#     ns1:ENVIRONMENT_IMPACT_CURRENT 66 ;
#     ns1:ENVIRONMENT_IMPACT_POTENTIAL 87 ;
#     ns1:EXTENSION_COUNT 0.0 ;
#     ns1:FIXED_LIGHTING_OUTLETS_COUNT 10 ;
#     ns1:FLOOR_DESCRIPTION "Solid, limited insulation (assumed)"^^xsd:string ;
#     ns1:FLOOR_HEIGHT 2.35 ;
#     ns1:GLAZED_AREA "Normal"^^xsd:string ;
#     ns1:GLAZED_TYPE "double glazing, unknown install date"^^xsd:string ;
#     ns1:HEATING_COST_CURRENT 376 ;
#     ns1:HEATING_COST_POTENTIAL 343 ;
#     ns1:HOTWATER_DESCRIPTION "From main system"^^xsd:string ;
#     ns1:HOT_WATER_COST_CURRENT 138 ;
#     ns1:HOT_WATER_COST_POTENTIAL 61 ;
#     ns1:HOT_WATER_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:HOT_WATER_ENV_EFF "Good"^^xsd:string ;
#     ns1:INSPECTION_DATE "2022-06-30"^^xsd:date ;
#     ns1:LIGHTING_COST_CURRENT 85 ;
#     ns1:LIGHTING_COST_POTENTIAL 57 ;
#     ns1:LIGHTING_DESCRIPTION "Low energy lighting in 50% of fixed outlets"^^xsd:string ;
#     ns1:LIGHTING_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:LIGHTING_ENV_EFF "Good"^^xsd:string ;
#     ns1:LMK_KEY "92574590f02ef114018d129d893df7449f66092bd663b824545f67889e361fee"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY "E07000130"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY_LABEL "Charnwood"^^xsd:string ;
#     ns1:LODGEMENT_DATE "2022-06-30"^^xsd:date ;
#     ns1:LODGEMENT_DATETIME "2022-06-30T16:40:25"^^xsd:dateTime ;
#     ns1:LOW_ENERGY_LIGHTING 50 ;
#     ns1:MAINHEATCONT_DESCRIPTION "Programmer, room thermostat and TRVs"^^xsd:string ;
#     ns1:MAINHEATC_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEATC_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_DESCRIPTION "Boiler and radiators, mains gas"^^xsd:string ;
#     ns1:MAINHEAT_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINS_GAS_FLAG "Y"^^xsd:string ;
#     ns1:MAIN_FUEL "mains gas (not community)"^^xsd:string ;
#     ns1:MECHANICAL_VENTILATION "natural"^^xsd:string ;
#     ns1:MULTI_GLAZE_PROPORTION 100.0 ;
#     ns1:NUMBER_HABITABLE_ROOMS 4.0 ;
#     ns1:NUMBER_HEATED_ROOMS 4.0 ;
#     ns1:NUMBER_OPEN_FIREPLACES 0 ;
#     ns1:PHOTO_SUPPLY 0.0 ;
#     ns1:POSTCODE "__REMOVED__"^^xsd:string ;
#     ns1:POSTTOWN "LEICESTER"^^xsd:string ;
#     ns1:POTENTIAL_ENERGY_EFFICIENCY 88 ;
#     ns1:POTENTIAL_ENERGY_RATING "B"^^xsd:string ;
#     ns1:PROPERTY_TYPE "House"^^xsd:string ;
#     ns1:ROOF_DESCRIPTION "Pitched, 100 mm loft insulation"^^xsd:string ;
#     ns1:ROOF_ENERGY_EFF "Average"^^xsd:string ;
#     ns1:ROOF_ENV_EFF "Average"^^xsd:string ;
#     ns1:SECONDHEAT_DESCRIPTION "None"^^xsd:string ;
#     ns1:SOLAR_WATER_HEATING_FLAG "N"^^xsd:string ;
#     ns1:TENURE "Rented (private)"^^xsd:string ;
#     ns1:TOTAL_FLOOR_AREA 59.0 ;
#     ns1:TRANSACTION_TYPE "rental"^^xsd:string ;
#     ns1:UPRN 200000844438 ;
#     ns1:UPRN_SOURCE "Energy Assessor"^^xsd:string ;
#     ns1:WALLS_DESCRIPTION "Cavity wall, as built, insulated (assumed)"^^xsd:string ;
#     ns1:WALLS_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:WALLS_ENV_EFF "Good"^^xsd:string ;
#     ns1:WINDOWS_DESCRIPTION "Fully double glazed"^^xsd:string ;
#     ns1:WINDOWS_ENERGY_EFF "Average"^^xsd:string ;
#     ns1:WINDOWS_ENV_EFF "Average"^^xsd:string ;
#     ns1:WIND_TURBINE_COUNT 0 .
#
# epc_data:Certificate_c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2 ns1:ADDRESS "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS1 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS2 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS3 "__REMOVED__"^^xsd:string ;
#     ns1:BUILDING_REFERENCE_NUMBER "10002800418"^^xsd:string ;
#     ns1:BUILT_FORM "Detached"^^xsd:string ;
#     ns1:CO2_EMISSIONS_CURRENT 2.7 ;
#     ns1:CO2_EMISSIONS_POTENTIAL 1.2 ;
#     ns1:CO2_EMISS_CURR_PER_FLOOR_AREA 51.0 ;
#     ns1:CONSTITUENCY "E14000625"^^xsd:string ;
#     ns1:CONSTITUENCY_LABEL "Charnwood"^^xsd:string ;
#     ns1:CONSTRUCTION_AGE_BAND "England and Wales: 1991-1995"^^xsd:string ;
#     ns1:COUNTY "Leicestershire"^^xsd:string ;
#     ns1:CURRENT_ENERGY_EFFICIENCY 64 ;
#     ns1:CURRENT_ENERGY_RATING "D"^^xsd:string ;
#     ns1:ENERGY_CONSUMPTION_CURRENT 289 ;
#     ns1:ENERGY_CONSUMPTION_POTENTIAL 119 ;
#     ns1:ENERGY_TARIFF "dual"^^xsd:string ;
#     ns1:ENVIRONMENT_IMPACT_CURRENT 63 ;
#     ns1:ENVIRONMENT_IMPACT_POTENTIAL 83 ;
#     ns1:EXTENSION_COUNT 0.0 ;
#     ns1:FIXED_LIGHTING_OUTLETS_COUNT 5 ;
#     ns1:FLOOR_DESCRIPTION "Solid, no insulation (assumed)"^^xsd:string ;
#     ns1:FLOOR_HEIGHT 2.31 ;
#     ns1:GLAZED_AREA "Normal"^^xsd:string ;
#     ns1:GLAZED_TYPE "double glazing, unknown install date"^^xsd:string ;
#     ns1:HEATING_COST_CURRENT 424 ;
#     ns1:HEATING_COST_POTENTIAL 381 ;
#     ns1:HOTWATER_DESCRIPTION "From main system"^^xsd:string ;
#     ns1:HOT_WATER_COST_CURRENT 108 ;
#     ns1:HOT_WATER_COST_POTENTIAL 67 ;
#     ns1:HOT_WATER_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:HOT_WATER_ENV_EFF "Good"^^xsd:string ;
#     ns1:INSPECTION_DATE "2022-06-27"^^xsd:date ;
#     ns1:LIGHTING_COST_CURRENT 94 ;
#     ns1:LIGHTING_COST_POTENTIAL 52 ;
#     ns1:LIGHTING_DESCRIPTION "Low energy lighting in 20% of fixed outlets"^^xsd:string ;
#     ns1:LIGHTING_ENERGY_EFF "Poor"^^xsd:string ;
#     ns1:LIGHTING_ENV_EFF "Poor"^^xsd:string ;
#     ns1:LMK_KEY "c629f08ff465bc7727911a7b3029ac42c18f5fa065e74b54eb4769c159c17bc2"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY "E07000130"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY_LABEL "Charnwood"^^xsd:string ;
#     ns1:LODGEMENT_DATE "2022-06-30"^^xsd:date ;
#     ns1:LODGEMENT_DATETIME "2022-06-30T12:02:18"^^xsd:dateTime ;
#     ns1:LOW_ENERGY_LIGHTING 20 ;
#     ns1:MAINHEATCONT_DESCRIPTION "Programmer, room thermostat and TRVs"^^xsd:string ;
#     ns1:MAINHEATC_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEATC_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_DESCRIPTION "Boiler and radiators, mains gas"^^xsd:string ;
#     ns1:MAINHEAT_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINS_GAS_FLAG "Y"^^xsd:string ;
#     ns1:MAIN_FUEL "mains gas (not community)"^^xsd:string ;
#     ns1:MECHANICAL_VENTILATION "natural"^^xsd:string ;
#     ns1:MULTI_GLAZE_PROPORTION 100.0 ;
#     ns1:NUMBER_HABITABLE_ROOMS 3.0 ;
#     ns1:NUMBER_HEATED_ROOMS 3.0 ;
#     ns1:NUMBER_OPEN_FIREPLACES 0 ;
#     ns1:PHOTO_SUPPLY 0.0 ;
#     ns1:POSTCODE "__REMOVED__"^^xsd:string ;
#     ns1:POSTTOWN "LEICESTER"^^xsd:string ;
#     ns1:POTENTIAL_ENERGY_EFFICIENCY 85 ;
#     ns1:POTENTIAL_ENERGY_RATING "B"^^xsd:string ;
#     ns1:PROPERTY_TYPE "Bungalow"^^xsd:string ;
#     ns1:ROOF_DESCRIPTION "Pitched, insulated (assumed)"^^xsd:string ;
#     ns1:ROOF_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:ROOF_ENV_EFF "Good"^^xsd:string ;
#     ns1:SECONDHEAT_DESCRIPTION "Room heaters, mains gas"^^xsd:string ;
#     ns1:SOLAR_WATER_HEATING_FLAG "N"^^xsd:string ;
#     ns1:TENURE "Owner-occupied"^^xsd:string ;
#     ns1:TOTAL_FLOOR_AREA 53.0 ;
#     ns1:TRANSACTION_TYPE "marketed sale"^^xsd:string ;
#     ns1:UPRN 100030427376 ;
#     ns1:UPRN_SOURCE "Energy Assessor"^^xsd:string ;
#     ns1:WALLS_DESCRIPTION "Cavity wall, as built, insulated (assumed)"^^xsd:string ;
#     ns1:WALLS_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:WALLS_ENV_EFF "Good"^^xsd:string ;
#     ns1:WINDOWS_DESCRIPTION "Fully double glazed"^^xsd:string ;
#     ns1:WINDOWS_ENERGY_EFF "Average"^^xsd:string ;
#     ns1:WINDOWS_ENV_EFF "Average"^^xsd:string ;
#     ns1:WIND_TURBINE_COUNT 0 .
#
# epc_data:Certificate_cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389 ns1:ADDRESS "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS1 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS2 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS3 "__REMOVED__"^^xsd:string ;
#     ns1:BUILDING_REFERENCE_NUMBER "10002572726"^^xsd:string ;
#     ns1:BUILT_FORM "Detached"^^xsd:string ;
#     ns1:CO2_EMISSIONS_CURRENT 6.0 ;
#     ns1:CO2_EMISSIONS_POTENTIAL 2.1 ;
#     ns1:CO2_EMISS_CURR_PER_FLOOR_AREA 60.0 ;
#     ns1:CONSTITUENCY "E14000625"^^xsd:string ;
#     ns1:CONSTITUENCY_LABEL "Charnwood"^^xsd:string ;
#     ns1:CONSTRUCTION_AGE_BAND "England and Wales: 1930-1949"^^xsd:string ;
#     ns1:COUNTY "Leicestershire"^^xsd:string ;
#     ns1:CURRENT_ENERGY_EFFICIENCY 53 ;
#     ns1:CURRENT_ENERGY_RATING "E"^^xsd:string ;
#     ns1:ENERGY_CONSUMPTION_CURRENT 341 ;
#     ns1:ENERGY_CONSUMPTION_POTENTIAL 116 ;
#     ns1:ENERGY_TARIFF "Single"^^xsd:string ;
#     ns1:ENVIRONMENT_IMPACT_CURRENT 45 ;
#     ns1:ENVIRONMENT_IMPACT_POTENTIAL 79 ;
#     ns1:EXTENSION_COUNT 0.0 ;
#     ns1:FIXED_LIGHTING_OUTLETS_COUNT 10 ;
#     ns1:FLOOR_DESCRIPTION "Suspended, no insulation (assumed)"^^xsd:string ;
#     ns1:FLOOR_HEIGHT 2.6 ;
#     ns1:GLAZED_AREA "Normal"^^xsd:string ;
#     ns1:GLAZED_TYPE "double glazing installed during or after 2002"^^xsd:string ;
#     ns1:HEATING_COST_CURRENT 966 ;
#     ns1:HEATING_COST_POTENTIAL 514 ;
#     ns1:HOTWATER_DESCRIPTION "From main system"^^xsd:string ;
#     ns1:HOT_WATER_COST_CURRENT 95 ;
#     ns1:HOT_WATER_COST_POTENTIAL 69 ;
#     ns1:HOT_WATER_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:HOT_WATER_ENV_EFF "Good"^^xsd:string ;
#     ns1:INSPECTION_DATE "2022-06-30"^^xsd:date ;
#     ns1:LIGHTING_COST_CURRENT 143 ;
#     ns1:LIGHTING_COST_POTENTIAL 79 ;
#     ns1:LIGHTING_DESCRIPTION "Low energy lighting in 20% of fixed outlets"^^xsd:string ;
#     ns1:LIGHTING_ENERGY_EFF "Poor"^^xsd:string ;
#     ns1:LIGHTING_ENV_EFF "Poor"^^xsd:string ;
#     ns1:LMK_KEY "cbd59b1d1971cdfd6b835182b487de95263c2ef043b407048ee0245d5d674389"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY "E07000129"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY_LABEL "Blaby"^^xsd:string ;
#     ns1:LODGEMENT_DATE "2022-06-30"^^xsd:date ;
#     ns1:LODGEMENT_DATETIME "2022-06-30T15:32:19"^^xsd:dateTime ;
#     ns1:LOW_ENERGY_LIGHTING 20 ;
#     ns1:MAINHEATCONT_DESCRIPTION "Programmer and room thermostat"^^xsd:string ;
#     ns1:MAINHEATC_ENERGY_EFF "Average"^^xsd:string ;
#     ns1:MAINHEATC_ENV_EFF "Average"^^xsd:string ;
#     ns1:MAINHEAT_DESCRIPTION "Boiler and radiators, mains gas"^^xsd:string ;
#     ns1:MAINHEAT_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINS_GAS_FLAG "Y"^^xsd:string ;
#     ns1:MAIN_FUEL "mains gas (not community)"^^xsd:string ;
#     ns1:MECHANICAL_VENTILATION "natural"^^xsd:string ;
#     ns1:MULTI_GLAZE_PROPORTION 90.0 ;
#     ns1:NUMBER_HABITABLE_ROOMS 5.0 ;
#     ns1:NUMBER_HEATED_ROOMS 5.0 ;
#     ns1:NUMBER_OPEN_FIREPLACES 0 ;
#     ns1:PHOTO_SUPPLY 0.0 ;
#     ns1:POSTCODE "__REMOVED__"^^xsd:string ;
#     ns1:POSTTOWN "LEICESTER"^^xsd:string ;
#     ns1:POTENTIAL_ENERGY_EFFICIENCY 83 ;
#     ns1:POTENTIAL_ENERGY_RATING "B"^^xsd:string ;
#     ns1:PROPERTY_TYPE "House"^^xsd:string ;
#     ns1:ROOF_DESCRIPTION "Pitched, 75 mm loft insulation"^^xsd:string ;
#     ns1:ROOF_ENERGY_EFF "Average"^^xsd:string ;
#     ns1:ROOF_ENV_EFF "Average"^^xsd:string ;
#     ns1:SECONDHEAT_DESCRIPTION "Room heaters, mains gas"^^xsd:string ;
#     ns1:SOLAR_WATER_HEATING_FLAG "N"^^xsd:string ;
#     ns1:TENURE "Owner-occupied"^^xsd:string ;
#     ns1:TOTAL_FLOOR_AREA 100.0 ;
#     ns1:TRANSACTION_TYPE "marketed sale"^^xsd:string ;
#     ns1:UPRN 100030393988 ;
#     ns1:UPRN_SOURCE "Energy Assessor"^^xsd:string ;
#     ns1:WALLS_DESCRIPTION "Solid brick, as built, no insulation (assumed)"^^xsd:string ;
#     ns1:WALLS_ENERGY_EFF "Very Poor"^^xsd:string ;
#     ns1:WALLS_ENV_EFF "Very Poor"^^xsd:string ;
#     ns1:WINDOWS_DESCRIPTION "Mostly double glazing"^^xsd:string ;
#     ns1:WINDOWS_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:WINDOWS_ENV_EFF "Good"^^xsd:string ;
#     ns1:WIND_TURBINE_COUNT 0 .
#
# epc_data:Certificate_e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e ns1:ADDRESS "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS1 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS2 "__REMOVED__"^^xsd:string ;
#     ns1:ADDRESS3 "__REMOVED__"^^xsd:string ;
#     ns1:BUILDING_REFERENCE_NUMBER "10002745187"^^xsd:string ;
#     ns1:BUILT_FORM "Semi-Detached"^^xsd:string ;
#     ns1:CO2_EMISSIONS_CURRENT 3.0 ;
#     ns1:CO2_EMISSIONS_POTENTIAL 1.6 ;
#     ns1:CO2_EMISS_CURR_PER_FLOOR_AREA 35.0 ;
#     ns1:CONSTITUENCY "E14000625"^^xsd:string ;
#     ns1:CONSTITUENCY_LABEL "Charnwood"^^xsd:string ;
#     ns1:CONSTRUCTION_AGE_BAND "England and Wales: 1930-1949"^^xsd:string ;
#     ns1:COUNTY "Leicestershire"^^xsd:string ;
#     ns1:CURRENT_ENERGY_EFFICIENCY 71 ;
#     ns1:CURRENT_ENERGY_RATING "C"^^xsd:string ;
#     ns1:ENERGY_CONSUMPTION_CURRENT 196 ;
#     ns1:ENERGY_CONSUMPTION_POTENTIAL 102 ;
#     ns1:ENERGY_TARIFF "Single"^^xsd:string ;
#     ns1:ENVIRONMENT_IMPACT_CURRENT 68 ;
#     ns1:ENVIRONMENT_IMPACT_POTENTIAL 83 ;
#     ns1:EXTENSION_COUNT 2.0 ;
#     ns1:FIXED_LIGHTING_OUTLETS_COUNT 12 ;
#     ns1:FLOOR_DESCRIPTION "Solid, no insulation (assumed)"^^xsd:string ;
#     ns1:FLOOR_HEIGHT 2.59 ;
#     ns1:GLAZED_AREA "Normal"^^xsd:string ;
#     ns1:GLAZED_TYPE "double glazing installed during or after 2002"^^xsd:string ;
#     ns1:HEATING_COST_CURRENT 505 ;
#     ns1:HEATING_COST_POTENTIAL 450 ;
#     ns1:HOTWATER_DESCRIPTION "From main system"^^xsd:string ;
#     ns1:HOT_WATER_COST_CURRENT 82 ;
#     ns1:HOT_WATER_COST_POTENTIAL 57 ;
#     ns1:HOT_WATER_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:HOT_WATER_ENV_EFF "Good"^^xsd:string ;
#     ns1:INSPECTION_DATE "2022-06-30"^^xsd:date ;
#     ns1:LIGHTING_COST_CURRENT 72 ;
#     ns1:LIGHTING_COST_POTENTIAL 72 ;
#     ns1:LIGHTING_DESCRIPTION "Low energy lighting in all fixed outlets"^^xsd:string ;
#     ns1:LIGHTING_ENERGY_EFF "Very Good"^^xsd:string ;
#     ns1:LIGHTING_ENV_EFF "Very Good"^^xsd:string ;
#     ns1:LMK_KEY "e1293cb1f5bbcab288ba201f2f9bed72d8d76c70aae5f47b5cf99680b5cd914e"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY "E07000130"^^xsd:string ;
#     ns1:LOCAL_AUTHORITY_LABEL "Charnwood"^^xsd:string ;
#     ns1:LODGEMENT_DATE "2022-06-30"^^xsd:date ;
#     ns1:LODGEMENT_DATETIME "2022-06-30T19:15:23"^^xsd:dateTime ;
#     ns1:LOW_ENERGY_LIGHTING 100 ;
#     ns1:MAINHEATCONT_DESCRIPTION "Programmer, room thermostat and TRVs"^^xsd:string ;
#     ns1:MAINHEATC_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEATC_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_DESCRIPTION "Boiler and radiators, mains gas"^^xsd:string ;
#     ns1:MAINHEAT_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:MAINHEAT_ENV_EFF "Good"^^xsd:string ;
#     ns1:MAINS_GAS_FLAG "Y"^^xsd:string ;
#     ns1:MAIN_FUEL "mains gas (not community)"^^xsd:string ;
#     ns1:MECHANICAL_VENTILATION "natural"^^xsd:string ;
#     ns1:MULTI_GLAZE_PROPORTION 100.0 ;
#     ns1:NUMBER_HABITABLE_ROOMS 5.0 ;
#     ns1:NUMBER_HEATED_ROOMS 5.0 ;
#     ns1:NUMBER_OPEN_FIREPLACES 0 ;
#     ns1:PHOTO_SUPPLY 0.0 ;
#     ns1:POSTCODE "__REMOVED__"^^xsd:string ;
#     ns1:POSTTOWN "LEICESTER"^^xsd:string ;
#     ns1:POTENTIAL_ENERGY_EFFICIENCY 85 ;
#     ns1:POTENTIAL_ENERGY_RATING "B"^^xsd:string ;
#     ns1:PROPERTY_TYPE "House"^^xsd:string ;
#     ns1:ROOF_DESCRIPTION "Pitched, 250 mm loft insulation"^^xsd:string ;
#     ns1:ROOF_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:ROOF_ENV_EFF "Good"^^xsd:string ;
#     ns1:SECONDHEAT_DESCRIPTION "None"^^xsd:string ;
#     ns1:SOLAR_WATER_HEATING_FLAG "N"^^xsd:string ;
#     ns1:TENURE "Owner-occupied"^^xsd:string ;
#     ns1:TOTAL_FLOOR_AREA 87.0 ;
#     ns1:TRANSACTION_TYPE "marketed sale"^^xsd:string ;
#     ns1:UPRN 100030429556 ;
#     ns1:UPRN_SOURCE "Energy Assessor"^^xsd:string ;
#     ns1:WALLS_DESCRIPTION "Cavity wall, as built, no insulation (assumed)"^^xsd:string ;
#     ns1:WALLS_ENERGY_EFF "Poor"^^xsd:string ;
#     ns1:WALLS_ENV_EFF "Poor"^^xsd:string ;
#     ns1:WINDOWS_DESCRIPTION "Fully double glazed"^^xsd:string ;
#     ns1:WINDOWS_ENERGY_EFF "Good"^^xsd:string ;
#     ns1:WINDOWS_ENV_EFF "Good"^^xsd:string ;
#     ns1:WIND_TURBINE_COUNT 0 .
