# %% [markdown]
# # Create_epc_vocab
#
# This Notebook creates a RDF vocabulary for use with the Energy Performance Certificate data.
#
# The vocabulary is saved as both RDF format (.ttl) and CSVW format (.csv & -metadata.json).
#
# **TO DO - The vocab for the recommendations.csv files.**

# %% [markdown]
# ## Setup

# %%
import csv
import json
import rdflib
import csvw_functions

# %% [markdown]
# ## Functions

# %% [markdown]
# ## get_glossary_info

# %%
with open('glossary_epc_domestic.txt') as f: glossary_text=f.read()

def get_glossary_info(col_name, st=glossary_text):
    ""
    a=st.find(col_name)
    b=st.find('\n',a+1)
    c=st.find('\n',b+1)
    
    variable_string=st[a+len(col_name):b].strip()
    
    description=st[b:c].strip()
    
    if not (variable_string.startswith('VARCHAR') 
            or variable_string.startswith('INT')
            or variable_string.startswith('DATE') 
            or variable_string.startswith('DECIMAL')
            or variable_string.startswith('DATETIME')
            or variable_string==''
           ):
    
        return get_glossary_info(col_name, st=st[a+len(col_name):])
    
    return col_name, variable_string, description

# %%
# test for single heading
get_glossary_info('LMK_KEY')
# Out:
# ('LMK_KEY',
#  'VARCHAR 64',
#  'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.')

# %%
# test for all headings
with open('certificates.csv') as f: 
    csvreader=csv.reader(f)
    headings=next(iter(csvreader))
for heading in headings:
    print(get_glossary_info(heading))
# Out:
# ('LMK_KEY', 'VARCHAR 64', 'Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API.')
# ('ADDRESS1', 'VARCHAR 84', 'First line of the address')
# ('ADDRESS2', 'VARCHAR 100', 'Second line of the address')
# ('ADDRESS3', 'VARCHAR 100', 'Third line of the address')
# ('POSTCODE', 'VARCHAR 8', 'The postcode of the property')
# ('BUILDING_REFERENCE_NUMBER', 'VARCHAR 12', 'Unique identifier for the property.')
# ('CURRENT_ENERGY_RATING', 'VARCHAR 8', "Current energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)")
# ('POTENTIAL_ENERGY_RATING', 'VARCHAR 8', "Estimated potential energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)")
# ('CURRENT_ENERGY_EFFICIENCY', 'INT', 'Based on cost of energy, i.e. energy required for space heating, water heating and lighting [in kWh/year] multiplied by fuel costs. (Â£/mÂ²/year where cost is derived from kWh).')
# ('POTENTIAL_ENERGY_EFFICIENCY', 'INT', 'The potential energy efficiency rating of the property.')
# ('PROPERTY_TYPE', 'VARCHAR 10', 'Describes the type of property such as House, Flat, Maisonette etc. This is the type differentiator for dwellings.')
# ('BUILT_FORM', 'VARCHAR 20', 'The building type of the Property e.g. Detached, Semi-Detached, Terrace etc. Together with the Property Type, the Build Form produces a structured description of the property')
# ('INSPECTION_DATE', 'DATE', 'The date that the inspection was actually carried out by the energy assessor')
# ('LOCAL_AUTHORITY', 'VARCHAR 9', 'Office for National Statistics (ONS) code. Local authority area in which the building is located.')
# ('CONSTITUENCY', 'VARCHAR 9', 'Office for National Statistics (ONS) code. Parliamentary constituency in which the building is located.')
# ('COUNTY', 'VARCHAR 24', 'County in which the building is located (where applicable)')
# ('LODGEMENT_DATE', 'DATE', 'Date lodged on the Energy Performance of Buildings Register')
# ('TRANSACTION_TYPE', 'VARCHAR 82', "Type of transaction that triggered EPC. For example, one of: marketed sale; non-marketed sale; new-dwelling; rental; not sale or rental; assessment for Green Deal; following Green Deal; FIT application; none of the above; RHI application; ECO assessment. Where the reason for the assessment is unknown by the energy assessor the transaction type will be recorded as 'none of the above'. Transaction types may be changed over time.")
# ('ENVIRONMENT_IMPACT_CURRENT', 'INT', "The Environmental Impact Rating. A measure of the property's current impact on the environment in terms of carbon dioxide (COâ‚‚) emissions. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)")
# ('ENVIRONMENT_IMPACT_POTENTIAL', 'INT', "The potential Environmental Impact Rating. A measure of the property's potential impact on the environment in terms of carbon dioxide (COâ‚‚) emissions after improvements have been carried out. The higher the rating the lower the COâ‚‚ emissions. (COâ‚‚ emissions in tonnes / year)")
# ('ENERGY_CONSUMPTION_CURRENT', 'INT', 'Current estimated total energy consumption for the property in a 12 month period (kWh/m2). Displayed on EPC as the current primary energy use per square metre of floor area.')
# ('ENERGY_CONSUMPTION_POTENTIAL', 'INT', 'Estimated potential total energy consumption for the Property in a 12 month period. Value is Kilowatt Hours per Square Metre (kWh/mÂ²)')
# ('CO2_EMISSIONS_CURRENT', 'DECIMAL', 'COâ‚‚ emissions per year in tonnes/year.')
# ('CO2_EMISS_CURR_PER_FLOOR_AREA', 'DECIMAL', 'COâ‚‚ emissions per square metre floor area per year in kg/mÂ²')
# ('CO2_EMISSIONS_POTENTIAL', 'DECIMAL', 'Estimated value in Tonnes per Year of the total COâ‚‚ emissions produced by the Property in 12 month period.')
# ('LIGHTING_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for lighting the property.')
# ('LIGHTING_COST_POTENTIAL', 'INT', 'GBP. Potential estimated annual energy costs for lighting the property after improvements have been made.')
# ('HEATING_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for heating the property.')
# ('HEATING_COST_POTENTIAL', 'INT', 'GBP. Potential annual energy costs for lighting the property after improvements have been made.')
# ('HOT_WATER_COST_CURRENT', 'INT', 'GBP. Current estimated annual energy costs for hot water')
# ('HOT_WATER_COST_POTENTIAL', 'INT', 'GBP. Potential estimated annual energy costs for hot water after improvements have been made.')
# ('TOTAL_FLOOR_AREA', 'DECIMAL', 'The total useful floor area is the total of all enclosed spaces measured to the internal face of the external walls, i.e. the gross floor area as measured in accordance with the guidance issued from time to time by the Royal Institute of Chartered Surveyors or by a body replacing that institution. (mÂ²)')
# ('ENERGY_TARIFF', 'VARCHAR 16', 'Type of electricity tariff for the property, e.g. single.')
# ('MAINS_GAS_FLAG', 'VARCHAR 1', 'Whether mains gas is available. Yes means that there is a gas meter or a gas-burning appliance in the dwelling. A closed-off gas pipe does not count.')
# ('FLOOR_LEVEL', 'VARCHAR 13', 'Flats and maisonettes only. Floor level relative to the lowest level of the property (0 for ground floor). If there is a basement, the basement is level 0 and the other floors are from 1 upwards')
# ('FLAT_TOP_STOREY', 'VARCHAR 1', 'Whether the flat is on the top storey')
# ('FLAT_STOREY_COUNT', 'INT', 'The number of storeys in the apartment block.')
# ('MAIN_HEATING_CONTROLS', 'VARCHAR 19', 'Type of main heating controls. Includes both main heating systems if there are two.')
# ('MULTI_GLAZE_PROPORTION', 'INT', 'The estimated banded range (e.g. 0% - 10%) of the total glazed area of the Property that is multiple glazed.')
# ('GLAZED_TYPE', 'VARCHAR 45', 'The type of glazing. From British Fenestration Rating Council or manufacturer declaration, one of; single; double; triple.')
# ('GLAZED_AREA', 'VARCHAR 22', 'Ranged estimate of the total glazed area of the Habitable Area.')
# ('EXTENSION_COUNT', 'INT', 'The number of extensions added to the property. Between 0 and 4.')
# ('NUMBER_HABITABLE_ROOMS', 'INT', 'Habitable rooms include any living room, sitting room, dining room, bedroom, study and similar; and also a non-separated conservatory. A kitchen/diner having a discrete seating area (with space for a table and four chairs) also counts as a habitable room. A non-separated conservatory adds to the habitable room count if it has an internal quality door between it and the dwelling. Excluded from the room count are any room used solely as a kitchen, utility room, bathroom, cloakroom, en-suite accommodation and similar and any hallway, stairs or landing; and also any room not having a window.')
# ('NUMBER_HEATED_ROOMS', 'INT', 'The number of heated rooms in the property if more than half of the habitable rooms are not heated.')
# ('LOW_ENERGY_LIGHTING', 'INT', 'The percentage of low energy lighting present in the property as a percentage of the total fixed lights in the property. 0% indicates that no low-energy lighting is present.')
# ('NUMBER_OPEN_FIREPLACES', 'INT', 'The number of Open Fireplaces in the Property. An Open Fireplace is a fireplace that still allows air to pass between the inside of the Property and the outside.')
# ('HOTWATER_DESCRIPTION', 'VARCHAR 95', 'Overall description of the property feature')
# ('HOT_WATER_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('HOT_WATER_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('FLOOR_DESCRIPTION', 'VARCHAR 91', 'Overall description of the property feature')
# ('FLOOR_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('FLOOR_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WINDOWS_DESCRIPTION', 'VARCHAR 54', 'Overall description of the property feature')
# ('WINDOWS_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WINDOWS_ENV_EFF', 'VARCHAR 9', 'WINDOWS. Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WALLS_DESCRIPTION', 'VARCHAR 121', 'Overall description of the property feature')
# ('WALLS_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('WALLS_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('SECONDHEAT_DESCRIPTION', 'VARCHAR 97', 'Overall description of the property feature')
# ('SHEATING_ENERGY_EFF', 'VARCHAR 3', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('SHEATING_ENV_EFF', 'VARCHAR 3', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('ROOF_DESCRIPTION', 'VARCHAR 92', 'Overall description of the property feature')
# ('ROOF_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('ROOF_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEAT_DESCRIPTION', 'VARCHAR 134', 'Overall description of the property feature')
# ('MAINHEAT_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEAT_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEATCONT_DESCRIPTION', 'VARCHAR 96', 'Overall description of the property feature')
# ('MAINHEATC_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAINHEATC_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('LIGHTING_DESCRIPTION', 'VARCHAR 91', 'Overall description of property feature. Total number of fixed lighting outlets and total number of low-energy fixed lighting outlets')
# ('LIGHTING_ENERGY_EFF', 'VARCHAR 9', 'Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('LIGHTING_ENV_EFF', 'VARCHAR 9', 'Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating.')
# ('MAIN_FUEL', 'VARCHAR 93', 'The type of fuel used to power the central heating e.g. Gas, Electricity')
# ('WIND_TURBINE_COUNT', 'INT', 'Number of wind turbines; 0 if none.')
# ('HEAT_LOSS_CORRIDOR', 'VARCHAR 17', 'Flats and maisonettes only. Indicates that the flat contains a corridor through which heat is lost. Heat loss corridor, one of: no corridor; heated corridor; unheated corridor')
# ('UNHEATED_CORRIDOR_LENGTH', 'DECIMAL', 'The total length of unheated corridor in the flat. Only populated if flat or maisonette contains unheated corridor. If unheated corridor, length of sheltered wall (mÂ²).')
# ('FLOOR_HEIGHT', 'DECIMAL', 'Average height of the storey in metres.')
# ('PHOTO_SUPPLY', 'INT', 'Percentage of photovoltaic area as a percentage of total roof area. 0% indicates that a Photovoltaic Supply is not present in the property.')
# ('SOLAR_WATER_HEATING_FLAG', 'VARCHAR 1', 'Indicates whether the heating in the Property is solar powered.')
# ('MECHANICAL_VENTILATION', 'VARCHAR 30', 'Identifies the type of mechanical ventilation the property has. This is required for the RdSAP calculation.')
# ('ADDRESS', '', 'Field containing the concatenation of address1, address2 and address3. Note that post code is recorded separately.')
# ('LOCAL_AUTHORITY_LABEL', '', 'The name of the local authority area in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Local Authority ONS Code.')
# ('CONSTITUENCY_LABEL', '', 'The name of the parliamentary constituency in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Constituency ONS Code.')
# ('POSTTOWN', 'VARCHAR 37', 'The post town of the property')
# ('CONSTRUCTION_AGE_BAND', 'VARCHAR 31', 'Age band when building part constructed. England & Wales only. One of: before 1900; 1900-1929; 1930-1949; 1950-1966; 1967-1975; 1976-1982; 1983-1990; 1991-1995; 1996-2002; 2003-2006; 2007-2011; 2012 onwards.')
# ('LODGEMENT_DATETIME', 'DATETIME2', 'Date and time lodged on the Energy Performance of Buildings Register.')
# ('TENURE', 'VARCHAR 100', 'Describes the tenure type of the property. One of: Owner-occupied; Rented (social); Rented (private).')
# ('FIXED_LIGHTING_OUTLETS_COUNT', 'INT', 'The number of fixed lighting outlets.')
# ('LOW_ENERGY_FIXED_LIGHT_COUNT', 'INT', 'The number of low-energy fixed lighting outlets.')
# ('UPRN', 'INT', 'The UPRN submitted by an assessor or alternatively from the departmentâ€™s address matching algorithm.')
# ('UPRN_SOURCE', 'VARCHAR 15', 'Populated with the values "Energy Assessor" or "Address Matched" to show how the UPRN was populated')

# %% [markdown]
# ## get_datatype

# %%
def get_datatype(variable_string):
    ""
    if variable_string=='':
        return 'string'
    elif variable_string.startswith('VARCHAR'):
        return 'string'
    elif variable_string.startswith('INT'):
        return 'integer'
    elif variable_string.startswith('DECIMAL'):
        return 'decimal'
    elif variable_string.startswith('DATETIME'):
        return {'base':'datetime','format':'yyyy-MM-dd HH:mm:ss'}
    elif variable_string.startswith('DATE'):
        return 'date'
    else:
        raise Exception

# %%
# check for all headings
for heading in headings:
    _, variable_string, description=get_glossary_info(heading)
    print(heading, get_datatype(variable_string))
# Out:
# LMK_KEY string
# ADDRESS1 string
# ADDRESS2 string
# ADDRESS3 string
# POSTCODE string
# BUILDING_REFERENCE_NUMBER string
# CURRENT_ENERGY_RATING string
# POTENTIAL_ENERGY_RATING string
# CURRENT_ENERGY_EFFICIENCY integer
# POTENTIAL_ENERGY_EFFICIENCY integer
# PROPERTY_TYPE string
# BUILT_FORM string
# INSPECTION_DATE date
# LOCAL_AUTHORITY string
# CONSTITUENCY string
# COUNTY string
# LODGEMENT_DATE date
# TRANSACTION_TYPE string
# ENVIRONMENT_IMPACT_CURRENT integer
# ENVIRONMENT_IMPACT_POTENTIAL integer
# ENERGY_CONSUMPTION_CURRENT integer
# ENERGY_CONSUMPTION_POTENTIAL integer
# CO2_EMISSIONS_CURRENT decimal
# CO2_EMISS_CURR_PER_FLOOR_AREA decimal
# CO2_EMISSIONS_POTENTIAL decimal
# LIGHTING_COST_CURRENT integer
# LIGHTING_COST_POTENTIAL integer
# HEATING_COST_CURRENT integer
# HEATING_COST_POTENTIAL integer
# HOT_WATER_COST_CURRENT integer
# HOT_WATER_COST_POTENTIAL integer
# TOTAL_FLOOR_AREA decimal
# ENERGY_TARIFF string
# MAINS_GAS_FLAG string
# FLOOR_LEVEL string
# FLAT_TOP_STOREY string
# FLAT_STOREY_COUNT integer
# MAIN_HEATING_CONTROLS string
# MULTI_GLAZE_PROPORTION integer
# GLAZED_TYPE string
# GLAZED_AREA string
# EXTENSION_COUNT integer
# NUMBER_HABITABLE_ROOMS integer
# NUMBER_HEATED_ROOMS integer
# LOW_ENERGY_LIGHTING integer
# NUMBER_OPEN_FIREPLACES integer
# HOTWATER_DESCRIPTION string
# HOT_WATER_ENERGY_EFF string
# HOT_WATER_ENV_EFF string
# FLOOR_DESCRIPTION string
# FLOOR_ENERGY_EFF string
# FLOOR_ENV_EFF string
# WINDOWS_DESCRIPTION string
# WINDOWS_ENERGY_EFF string
# WINDOWS_ENV_EFF string
# WALLS_DESCRIPTION string
# WALLS_ENERGY_EFF string
# WALLS_ENV_EFF string
# SECONDHEAT_DESCRIPTION string
# SHEATING_ENERGY_EFF string
# SHEATING_ENV_EFF string
# ROOF_DESCRIPTION string
# ROOF_ENERGY_EFF string
# ROOF_ENV_EFF string
# MAINHEAT_DESCRIPTION string
# MAINHEAT_ENERGY_EFF string
# MAINHEAT_ENV_EFF string
# MAINHEATCONT_DESCRIPTION string
# MAINHEATC_ENERGY_EFF string
# MAINHEATC_ENV_EFF string
# LIGHTING_DESCRIPTION string
# LIGHTING_ENERGY_EFF string
# LIGHTING_ENV_EFF string
# MAIN_FUEL string
# WIND_TURBINE_COUNT integer
# HEAT_LOSS_CORRIDOR string
# UNHEATED_CORRIDOR_LENGTH decimal
# FLOOR_HEIGHT decimal
# PHOTO_SUPPLY integer
# SOLAR_WATER_HEATING_FLAG string
# MECHANICAL_VENTILATION string
# ADDRESS string
# LOCAL_AUTHORITY_LABEL string
# CONSTITUENCY_LABEL string
# POSTTOWN string
# CONSTRUCTION_AGE_BAND string
# LODGEMENT_DATETIME {'base': 'datetime', 'format': 'yyyy-MM-dd HH:mm:ss'}
# TENURE string
# FIXED_LIGHTING_OUTLETS_COUNT integer
# LOW_ENERGY_FIXED_LIGHT_COUNT integer
# UPRN integer
# UPRN_SOURCE string

# %% [markdown]
# ## Create csv file
#
# This CSV file contains the information about the EPC vocabulary. This can be converted to RDF using the CSVW metadata file below.

# %%
with open('epc_vocab.csv','w',newline='') as f:
    
    csvwriter=csv.writer(f)
    
    csvwriter.writerow(
        ['id',
         'label',
         'comment',
         'original_epc_datatype',
         'csvw_datatype'
        ])
    
    # epc_vocab:datatype
    csvwriter.writerow(
        ['original_epc_datatype',
         'original_epc_datatype',
         'The datatype of a EPC variable, as given in the EPC guidance notes.',
         ''
        ])
    
    # epc_vocab:datatype
    csvwriter.writerow(
        ['csvw_datatype',
         'csvw_datatype',
         'The CSVW datatype of a epc_vocab Property.',
         ''
        ])
    
    for heading in headings:
        
        heading, variable_string, description=get_glossary_info(heading)
        
        datatype=get_datatype(variable_string)
        
        cleaned_datatypes={
            'MULTI_GLAZE_PROPORTION':'decimal',
            'EXTENSION_COUNT':'decimal',
            'NUMBER_HABITABLE_ROOMS':'decimal',
            'NUMBER_HEATED_ROOMS':'decimal',
            'PHOTO_SUPPLY':'decimal'
        }
        if heading in cleaned_datatypes:
            datatype=cleaned_datatypes[heading]
        
        
        csvwriter.writerow(
            [heading,
             heading,
             description,
             variable_string,
             datatype
            ])

# %% [markdown]
# ## Create metadata file

# %%
metadata_table_dict={
    "@context": "http://www.w3.org/ns/csvw",
    "@type": "Table",
    'url': 'epc_vocab.csv',
    'tableSchema':{
        'columns':[
            {
                'name':'id',
                'suppressOutput': True,
                'titles':'id',
            },
            {
                'name':'label',
                'titles':'label',
                'aboutUrl': 'http://purl.org/berg/epc_vocab#{id}',
                'propertyUrl': 'rdfs:label'
            },
            {
                'name':'comment',
                'titles':'comment',
                'aboutUrl': 'http://purl.org/berg/epc_vocab#{id}',
                'propertyUrl': 'rdfs:comment'
            },
            {
                'name':'original_epc_datatype',
                'titles':'original_epc_datatype',
                'aboutUrl': 'http://purl.org/berg/epc_vocab#{id}',
                'propertyUrl': 'http://purl.org/berg/epc_vocab#original_epc_datatype'
            },
            {
                'name':'csvw_datatype',
                'titles':'csvw_datatype',
                'aboutUrl': 'http://purl.org/berg/epc_vocab#{id}',
                'propertyUrl': 'http://purl.org/berg/epc_vocab#csvw_datatype'
            },
            {
                'name':'type',
                'virtual':True,
                'aboutUrl': 'http://purl.org/berg/epc_vocab#{id}',
                'propertyUrl': 'rdf:type',
                'valueUrl': 'rdf:Property'
            }
            
        ]
    }
    
    
    
}
with open('epc_vocab.csv-metadata.json','w') as f:
    json.dump(metadata_table_dict,f,indent=4)

# %% [markdown]
# ## Create rdf file

# %%
annotated_table_group_dict=csvw_functions.create_annotated_table_group('epc_vocab.csv-metadata.json')
csvw_functions.display_annotated_table_group_dict(annotated_table_group_dict)
print('errors: ',csvw_functions.get_errors(annotated_table_group_dict))
rdf_ntriples=csvw_functions.create_rdf(annotated_table_group_dict,mode='minimal')
#print(rdf_ntriples)
g=rdflib.Graph().parse(data=rdf_ntriples, format='ntriples')
g.bind('sosa',rdflib.SOSA)
g.bind('epc_data',rdflib.URIRef('http://purl.org/berg/epc_data#'))
g.bind('epc_vocab',rdflib.URIRef('http://purl.org/berg/epc_vocab#'))
g.serialize('epc_vocab.ttl',format='ttl')
print(g.serialize(format='ttl'))
# Out:
# errors:  []
# @prefix epc_vocab: <http://purl.org/berg/epc_vocab#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# epc_vocab:ADDRESS a rdf:Property ;
#     rdfs:label "ADDRESS"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     rdfs:comment "Field containing the concatenation of address1, address2 and address3. Note that post code is recorded separately."^^xsd:string .
#
# epc_vocab:ADDRESS1 a rdf:Property ;
#     rdfs:label "ADDRESS1"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 84"^^xsd:string ;
#     rdfs:comment "First line of the address"^^xsd:string .
#
# epc_vocab:ADDRESS2 a rdf:Property ;
#     rdfs:label "ADDRESS2"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 100"^^xsd:string ;
#     rdfs:comment "Second line of the address"^^xsd:string .
#
# epc_vocab:ADDRESS3 a rdf:Property ;
#     rdfs:label "ADDRESS3"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 100"^^xsd:string ;
#     rdfs:comment "Third line of the address"^^xsd:string .
#
# epc_vocab:BUILDING_REFERENCE_NUMBER a rdf:Property ;
#     rdfs:label "BUILDING_REFERENCE_NUMBER"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 12"^^xsd:string ;
#     rdfs:comment "Unique identifier for the property."^^xsd:string .
#
# epc_vocab:BUILT_FORM a rdf:Property ;
#     rdfs:label "BUILT_FORM"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 20"^^xsd:string ;
#     rdfs:comment "The building type of the Property e.g. Detached, Semi-Detached, Terrace etc. Together with the Property Type, the Build Form produces a structured description of the property"^^xsd:string .
#
# epc_vocab:CO2_EMISSIONS_CURRENT a rdf:Property ;
#     rdfs:label "CO2_EMISSIONS_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "CO₂ emissions per year in tonnes/year."^^xsd:string .
#
# epc_vocab:CO2_EMISSIONS_POTENTIAL a rdf:Property ;
#     rdfs:label "CO2_EMISSIONS_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "Estimated value in Tonnes per Year of the total CO₂ emissions produced by the Property in 12 month period."^^xsd:string .
#
# epc_vocab:CO2_EMISS_CURR_PER_FLOOR_AREA a rdf:Property ;
#     rdfs:label "CO2_EMISS_CURR_PER_FLOOR_AREA"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "CO₂ emissions per square metre floor area per year in kg/m²"^^xsd:string .
#
# epc_vocab:CONSTITUENCY a rdf:Property ;
#     rdfs:label "CONSTITUENCY"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Office for National Statistics (ONS) code. Parliamentary constituency in which the building is located."^^xsd:string .
#
# epc_vocab:CONSTITUENCY_LABEL a rdf:Property ;
#     rdfs:label "CONSTITUENCY_LABEL"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     rdfs:comment "The name of the parliamentary constituency in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Constituency ONS Code."^^xsd:string .
#
# epc_vocab:CONSTRUCTION_AGE_BAND a rdf:Property ;
#     rdfs:label "CONSTRUCTION_AGE_BAND"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 31"^^xsd:string ;
#     rdfs:comment "Age band when building part constructed. England & Wales only. One of: before 1900; 1900-1929; 1930-1949; 1950-1966; 1967-1975; 1976-1982; 1983-1990; 1991-1995; 1996-2002; 2003-2006; 2007-2011; 2012 onwards."^^xsd:string .
#
# epc_vocab:COUNTY a rdf:Property ;
#     rdfs:label "COUNTY"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 24"^^xsd:string ;
#     rdfs:comment "County in which the building is located (where applicable)"^^xsd:string .
#
# epc_vocab:CURRENT_ENERGY_EFFICIENCY a rdf:Property ;
#     rdfs:label "CURRENT_ENERGY_EFFICIENCY"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Based on cost of energy, i.e. energy required for space heating, water heating and lighting [in kWh/year] multiplied by fuel costs. (£/m²/year where cost is derived from kWh)."^^xsd:string .
#
# epc_vocab:CURRENT_ENERGY_RATING a rdf:Property ;
#     rdfs:label "CURRENT_ENERGY_RATING"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 8"^^xsd:string ;
#     rdfs:comment "Current energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)"^^xsd:string .
#
# epc_vocab:ENERGY_CONSUMPTION_CURRENT a rdf:Property ;
#     rdfs:label "ENERGY_CONSUMPTION_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Current estimated total energy consumption for the property in a 12 month period (kWh/m2). Displayed on EPC as the current primary energy use per square metre of floor area."^^xsd:string .
#
# epc_vocab:ENERGY_CONSUMPTION_POTENTIAL a rdf:Property ;
#     rdfs:label "ENERGY_CONSUMPTION_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Estimated potential total energy consumption for the Property in a 12 month period. Value is Kilowatt Hours per Square Metre (kWh/m²)"^^xsd:string .
#
# epc_vocab:ENERGY_TARIFF a rdf:Property ;
#     rdfs:label "ENERGY_TARIFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 16"^^xsd:string ;
#     rdfs:comment "Type of electricity tariff for the property, e.g. single."^^xsd:string .
#
# epc_vocab:ENVIRONMENT_IMPACT_CURRENT a rdf:Property ;
#     rdfs:label "ENVIRONMENT_IMPACT_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The Environmental Impact Rating. A measure of the property's current impact on the environment in terms of carbon dioxide (CO₂) emissions. The higher the rating the lower the CO₂ emissions. (CO₂ emissions in tonnes / year)"^^xsd:string .
#
# epc_vocab:ENVIRONMENT_IMPACT_POTENTIAL a rdf:Property ;
#     rdfs:label "ENVIRONMENT_IMPACT_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The potential Environmental Impact Rating. A measure of the property's potential impact on the environment in terms of carbon dioxide (CO₂) emissions after improvements have been carried out. The higher the rating the lower the CO₂ emissions. (CO₂ emissions in tonnes / year)"^^xsd:string .
#
# epc_vocab:EXTENSION_COUNT a rdf:Property ;
#     rdfs:label "EXTENSION_COUNT"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of extensions added to the property. Between 0 and 4."^^xsd:string .
#
# epc_vocab:FIXED_LIGHTING_OUTLETS_COUNT a rdf:Property ;
#     rdfs:label "FIXED_LIGHTING_OUTLETS_COUNT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of fixed lighting outlets."^^xsd:string .
#
# epc_vocab:FLAT_STOREY_COUNT a rdf:Property ;
#     rdfs:label "FLAT_STOREY_COUNT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of storeys in the apartment block."^^xsd:string .
#
# epc_vocab:FLAT_TOP_STOREY a rdf:Property ;
#     rdfs:label "FLAT_TOP_STOREY"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 1"^^xsd:string ;
#     rdfs:comment "Whether the flat is on the top storey"^^xsd:string .
#
# epc_vocab:FLOOR_DESCRIPTION a rdf:Property ;
#     rdfs:label "FLOOR_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 91"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:FLOOR_ENERGY_EFF a rdf:Property ;
#     rdfs:label "FLOOR_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:FLOOR_ENV_EFF a rdf:Property ;
#     rdfs:label "FLOOR_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:FLOOR_HEIGHT a rdf:Property ;
#     rdfs:label "FLOOR_HEIGHT"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "Average height of the storey in metres."^^xsd:string .
#
# epc_vocab:FLOOR_LEVEL a rdf:Property ;
#     rdfs:label "FLOOR_LEVEL"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 13"^^xsd:string ;
#     rdfs:comment "Flats and maisonettes only. Floor level relative to the lowest level of the property (0 for ground floor). If there is a basement, the basement is level 0 and the other floors are from 1 upwards"^^xsd:string .
#
# epc_vocab:GLAZED_AREA a rdf:Property ;
#     rdfs:label "GLAZED_AREA"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 22"^^xsd:string ;
#     rdfs:comment "Ranged estimate of the total glazed area of the Habitable Area."^^xsd:string .
#
# epc_vocab:GLAZED_TYPE a rdf:Property ;
#     rdfs:label "GLAZED_TYPE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 45"^^xsd:string ;
#     rdfs:comment "The type of glazing. From British Fenestration Rating Council or manufacturer declaration, one of; single; double; triple."^^xsd:string .
#
# epc_vocab:HEATING_COST_CURRENT a rdf:Property ;
#     rdfs:label "HEATING_COST_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Current estimated annual energy costs for heating the property."^^xsd:string .
#
# epc_vocab:HEATING_COST_POTENTIAL a rdf:Property ;
#     rdfs:label "HEATING_COST_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Potential annual energy costs for lighting the property after improvements have been made."^^xsd:string .
#
# epc_vocab:HEAT_LOSS_CORRIDOR a rdf:Property ;
#     rdfs:label "HEAT_LOSS_CORRIDOR"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 17"^^xsd:string ;
#     rdfs:comment "Flats and maisonettes only. Indicates that the flat contains a corridor through which heat is lost. Heat loss corridor, one of: no corridor; heated corridor; unheated corridor"^^xsd:string .
#
# epc_vocab:HOTWATER_DESCRIPTION a rdf:Property ;
#     rdfs:label "HOTWATER_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 95"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:HOT_WATER_COST_CURRENT a rdf:Property ;
#     rdfs:label "HOT_WATER_COST_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Current estimated annual energy costs for hot water"^^xsd:string .
#
# epc_vocab:HOT_WATER_COST_POTENTIAL a rdf:Property ;
#     rdfs:label "HOT_WATER_COST_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Potential estimated annual energy costs for hot water after improvements have been made."^^xsd:string .
#
# epc_vocab:HOT_WATER_ENERGY_EFF a rdf:Property ;
#     rdfs:label "HOT_WATER_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:HOT_WATER_ENV_EFF a rdf:Property ;
#     rdfs:label "HOT_WATER_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:INSPECTION_DATE a rdf:Property ;
#     rdfs:label "INSPECTION_DATE"^^xsd:string ;
#     epc_vocab:csvw_datatype "date"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DATE"^^xsd:string ;
#     rdfs:comment "The date that the inspection was actually carried out by the energy assessor"^^xsd:string .
#
# epc_vocab:LIGHTING_COST_CURRENT a rdf:Property ;
#     rdfs:label "LIGHTING_COST_CURRENT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Current estimated annual energy costs for lighting the property."^^xsd:string .
#
# epc_vocab:LIGHTING_COST_POTENTIAL a rdf:Property ;
#     rdfs:label "LIGHTING_COST_POTENTIAL"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "GBP. Potential estimated annual energy costs for lighting the property after improvements have been made."^^xsd:string .
#
# epc_vocab:LIGHTING_DESCRIPTION a rdf:Property ;
#     rdfs:label "LIGHTING_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 91"^^xsd:string ;
#     rdfs:comment "Overall description of property feature. Total number of fixed lighting outlets and total number of low-energy fixed lighting outlets"^^xsd:string .
#
# epc_vocab:LIGHTING_ENERGY_EFF a rdf:Property ;
#     rdfs:label "LIGHTING_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:LIGHTING_ENV_EFF a rdf:Property ;
#     rdfs:label "LIGHTING_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:LMK_KEY a rdf:Property ;
#     rdfs:label "LMK_KEY"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 64"^^xsd:string ;
#     rdfs:comment "Individual lodgement identifier. Guaranteed to be unique and can be used to identify a certificate in the downloads and the API."^^xsd:string .
#
# epc_vocab:LOCAL_AUTHORITY a rdf:Property ;
#     rdfs:label "LOCAL_AUTHORITY"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Office for National Statistics (ONS) code. Local authority area in which the building is located."^^xsd:string .
#
# epc_vocab:LOCAL_AUTHORITY_LABEL a rdf:Property ;
#     rdfs:label "LOCAL_AUTHORITY_LABEL"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     rdfs:comment "The name of the local authority area in which the building is located. This field is for additional information only and should not be relied upon: please refer to the Local Authority ONS Code."^^xsd:string .
#
# epc_vocab:LODGEMENT_DATE a rdf:Property ;
#     rdfs:label "LODGEMENT_DATE"^^xsd:string ;
#     epc_vocab:csvw_datatype "date"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DATE"^^xsd:string ;
#     rdfs:comment "Date lodged on the Energy Performance of Buildings Register"^^xsd:string .
#
# epc_vocab:LODGEMENT_DATETIME a rdf:Property ;
#     rdfs:label "LODGEMENT_DATETIME"^^xsd:string ;
#     epc_vocab:csvw_datatype "{'base': 'datetime', 'format': 'yyyy-MM-dd HH:mm:ss'}"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DATETIME2"^^xsd:string ;
#     rdfs:comment "Date and time lodged on the Energy Performance of Buildings Register."^^xsd:string .
#
# epc_vocab:LOW_ENERGY_FIXED_LIGHT_COUNT a rdf:Property ;
#     rdfs:label "LOW_ENERGY_FIXED_LIGHT_COUNT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of low-energy fixed lighting outlets."^^xsd:string .
#
# epc_vocab:LOW_ENERGY_LIGHTING a rdf:Property ;
#     rdfs:label "LOW_ENERGY_LIGHTING"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The percentage of low energy lighting present in the property as a percentage of the total fixed lights in the property. 0% indicates that no low-energy lighting is present."^^xsd:string .
#
# epc_vocab:MAINHEATCONT_DESCRIPTION a rdf:Property ;
#     rdfs:label "MAINHEATCONT_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 96"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:MAINHEATC_ENERGY_EFF a rdf:Property ;
#     rdfs:label "MAINHEATC_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:MAINHEATC_ENV_EFF a rdf:Property ;
#     rdfs:label "MAINHEATC_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:MAINHEAT_DESCRIPTION a rdf:Property ;
#     rdfs:label "MAINHEAT_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 134"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:MAINHEAT_ENERGY_EFF a rdf:Property ;
#     rdfs:label "MAINHEAT_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:MAINHEAT_ENV_EFF a rdf:Property ;
#     rdfs:label "MAINHEAT_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:MAINS_GAS_FLAG a rdf:Property ;
#     rdfs:label "MAINS_GAS_FLAG"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 1"^^xsd:string ;
#     rdfs:comment "Whether mains gas is available. Yes means that there is a gas meter or a gas-burning appliance in the dwelling. A closed-off gas pipe does not count."^^xsd:string .
#
# epc_vocab:MAIN_FUEL a rdf:Property ;
#     rdfs:label "MAIN_FUEL"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 93"^^xsd:string ;
#     rdfs:comment "The type of fuel used to power the central heating e.g. Gas, Electricity"^^xsd:string .
#
# epc_vocab:MAIN_HEATING_CONTROLS a rdf:Property ;
#     rdfs:label "MAIN_HEATING_CONTROLS"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 19"^^xsd:string ;
#     rdfs:comment "Type of main heating controls. Includes both main heating systems if there are two."^^xsd:string .
#
# epc_vocab:MECHANICAL_VENTILATION a rdf:Property ;
#     rdfs:label "MECHANICAL_VENTILATION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 30"^^xsd:string ;
#     rdfs:comment "Identifies the type of mechanical ventilation the property has. This is required for the RdSAP calculation."^^xsd:string .
#
# epc_vocab:MULTI_GLAZE_PROPORTION a rdf:Property ;
#     rdfs:label "MULTI_GLAZE_PROPORTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The estimated banded range (e.g. 0% - 10%) of the total glazed area of the Property that is multiple glazed."^^xsd:string .
#
# epc_vocab:NUMBER_HABITABLE_ROOMS a rdf:Property ;
#     rdfs:label "NUMBER_HABITABLE_ROOMS"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Habitable rooms include any living room, sitting room, dining room, bedroom, study and similar; and also a non-separated conservatory. A kitchen/diner having a discrete seating area (with space for a table and four chairs) also counts as a habitable room. A non-separated conservatory adds to the habitable room count if it has an internal quality door between it and the dwelling. Excluded from the room count are any room used solely as a kitchen, utility room, bathroom, cloakroom, en-suite accommodation and similar and any hallway, stairs or landing; and also any room not having a window."^^xsd:string .
#
# epc_vocab:NUMBER_HEATED_ROOMS a rdf:Property ;
#     rdfs:label "NUMBER_HEATED_ROOMS"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of heated rooms in the property if more than half of the habitable rooms are not heated."^^xsd:string .
#
# epc_vocab:NUMBER_OPEN_FIREPLACES a rdf:Property ;
#     rdfs:label "NUMBER_OPEN_FIREPLACES"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The number of Open Fireplaces in the Property. An Open Fireplace is a fireplace that still allows air to pass between the inside of the Property and the outside."^^xsd:string .
#
# epc_vocab:PHOTO_SUPPLY a rdf:Property ;
#     rdfs:label "PHOTO_SUPPLY"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Percentage of photovoltaic area as a percentage of total roof area. 0% indicates that a Photovoltaic Supply is not present in the property."^^xsd:string .
#
# epc_vocab:POSTCODE a rdf:Property ;
#     rdfs:label "POSTCODE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 8"^^xsd:string ;
#     rdfs:comment "The postcode of the property"^^xsd:string .
#
# epc_vocab:POSTTOWN a rdf:Property ;
#     rdfs:label "POSTTOWN"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 37"^^xsd:string ;
#     rdfs:comment "The post town of the property"^^xsd:string .
#
# epc_vocab:POTENTIAL_ENERGY_EFFICIENCY a rdf:Property ;
#     rdfs:label "POTENTIAL_ENERGY_EFFICIENCY"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The potential energy efficiency rating of the property."^^xsd:string .
#
# epc_vocab:POTENTIAL_ENERGY_RATING a rdf:Property ;
#     rdfs:label "POTENTIAL_ENERGY_RATING"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 8"^^xsd:string ;
#     rdfs:comment "Estimated potential energy rating converted into a linear 'A to G' rating (where A is the most energy efficient and G is the least energy efficient)"^^xsd:string .
#
# epc_vocab:PROPERTY_TYPE a rdf:Property ;
#     rdfs:label "PROPERTY_TYPE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 10"^^xsd:string ;
#     rdfs:comment "Describes the type of property such as House, Flat, Maisonette etc. This is the type differentiator for dwellings."^^xsd:string .
#
# epc_vocab:ROOF_DESCRIPTION a rdf:Property ;
#     rdfs:label "ROOF_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 92"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:ROOF_ENERGY_EFF a rdf:Property ;
#     rdfs:label "ROOF_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:ROOF_ENV_EFF a rdf:Property ;
#     rdfs:label "ROOF_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:SECONDHEAT_DESCRIPTION a rdf:Property ;
#     rdfs:label "SECONDHEAT_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 97"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:SHEATING_ENERGY_EFF a rdf:Property ;
#     rdfs:label "SHEATING_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 3"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:SHEATING_ENV_EFF a rdf:Property ;
#     rdfs:label "SHEATING_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 3"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:SOLAR_WATER_HEATING_FLAG a rdf:Property ;
#     rdfs:label "SOLAR_WATER_HEATING_FLAG"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 1"^^xsd:string ;
#     rdfs:comment "Indicates whether the heating in the Property is solar powered."^^xsd:string .
#
# epc_vocab:TENURE a rdf:Property ;
#     rdfs:label "TENURE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 100"^^xsd:string ;
#     rdfs:comment "Describes the tenure type of the property. One of: Owner-occupied; Rented (social); Rented (private)."^^xsd:string .
#
# epc_vocab:TOTAL_FLOOR_AREA a rdf:Property ;
#     rdfs:label "TOTAL_FLOOR_AREA"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "The total useful floor area is the total of all enclosed spaces measured to the internal face of the external walls, i.e. the gross floor area as measured in accordance with the guidance issued from time to time by the Royal Institute of Chartered Surveyors or by a body replacing that institution. (m²)"^^xsd:string .
#
# epc_vocab:TRANSACTION_TYPE a rdf:Property ;
#     rdfs:label "TRANSACTION_TYPE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 82"^^xsd:string ;
#     rdfs:comment "Type of transaction that triggered EPC. For example, one of: marketed sale; non-marketed sale; new-dwelling; rental; not sale or rental; assessment for Green Deal; following Green Deal; FIT application; none of the above; RHI application; ECO assessment. Where the reason for the assessment is unknown by the energy assessor the transaction type will be recorded as 'none of the above'. Transaction types may be changed over time."^^xsd:string .
#
# epc_vocab:UNHEATED_CORRIDOR_LENGTH a rdf:Property ;
#     rdfs:label "UNHEATED_CORRIDOR_LENGTH"^^xsd:string ;
#     epc_vocab:csvw_datatype "decimal"^^xsd:string ;
#     epc_vocab:original_epc_datatype "DECIMAL"^^xsd:string ;
#     rdfs:comment "The total length of unheated corridor in the flat. Only populated if flat or maisonette contains unheated corridor. If unheated corridor, length of sheltered wall (m²)."^^xsd:string .
#
# epc_vocab:UPRN a rdf:Property ;
#     rdfs:label "UPRN"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "The UPRN submitted by an assessor or alternatively from the department’s address matching algorithm."^^xsd:string .
#
# epc_vocab:UPRN_SOURCE a rdf:Property ;
#     rdfs:label "UPRN_SOURCE"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 15"^^xsd:string ;
#     rdfs:comment "Populated with the values \"Energy Assessor\" or \"Address Matched\" to show how the UPRN was populated"^^xsd:string .
#
# epc_vocab:WALLS_DESCRIPTION a rdf:Property ;
#     rdfs:label "WALLS_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 121"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:WALLS_ENERGY_EFF a rdf:Property ;
#     rdfs:label "WALLS_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:WALLS_ENV_EFF a rdf:Property ;
#     rdfs:label "WALLS_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:WINDOWS_DESCRIPTION a rdf:Property ;
#     rdfs:label "WINDOWS_DESCRIPTION"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 54"^^xsd:string ;
#     rdfs:comment "Overall description of the property feature"^^xsd:string .
#
# epc_vocab:WINDOWS_ENERGY_EFF a rdf:Property ;
#     rdfs:label "WINDOWS_ENERGY_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "Energy efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:WINDOWS_ENV_EFF a rdf:Property ;
#     rdfs:label "WINDOWS_ENV_EFF"^^xsd:string ;
#     epc_vocab:csvw_datatype "string"^^xsd:string ;
#     epc_vocab:original_epc_datatype "VARCHAR 9"^^xsd:string ;
#     rdfs:comment "WINDOWS. Environmental efficiency rating. One of: very good; good; average; poor; very poor. On actual energy certificate shown as one to five star rating."^^xsd:string .
#
# epc_vocab:WIND_TURBINE_COUNT a rdf:Property ;
#     rdfs:label "WIND_TURBINE_COUNT"^^xsd:string ;
#     epc_vocab:csvw_datatype "integer"^^xsd:string ;
#     epc_vocab:original_epc_datatype "INT"^^xsd:string ;
#     rdfs:comment "Number of wind turbines; 0 if none."^^xsd:string .
#
# epc_vocab:csvw_datatype a rdf:Property ;
#     rdfs:label "csvw_datatype"^^xsd:string ;
#     rdfs:comment "The CSVW datatype of a epc_vocab Property."^^xsd:string .
#
# epc_vocab:original_epc_datatype a rdf:Property ;
#     rdfs:label "original_epc_datatype"^^xsd:string ;
#     rdfs:comment "The datatype of a EPC variable, as given in the EPC guidance notes."^^xsd:string .
